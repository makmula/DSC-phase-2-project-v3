# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Virgilia Antonucci and Makonnen Sharpe
# * Student pace: full time
# * Scheduled project review date/time:
# * Instructor name: Joseph Mata
# * Blog post URL:

# %%
# Your code here - remember to use markdown cells for comments as well!

# %% [markdown]
# # Business Problem
# Your company now sees all the big companies creating original video content and they want to get in on the fun. They have decided to create a new movie studio, but they don’t know anything about creating movies. You are charged with exploring what types of films are currently doing the best at the box office. You must then translate those findings into actionable insights that the head of your company's new movie studio can use to help decide what type of films to create.

# %% [markdown]
# We must load relevant libraries and the datasets

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# First step is to look through the data.

# %%
movie_gross = pd.read_csv('zippedData/bom.movie_gross.csv.gz')

movie_gross.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
# Ensure the 'domestic_gross' and 'foreign_gross' columns are numeric (if they aren't already)
movie_gross['domestic_gross'] = pd.to_numeric(movie_gross['domestic_gross'], errors='coerce')
movie_gross['foreign_gross'] = pd.to_numeric(movie_gross['foreign_gross'], errors='coerce')

# Create the 'total_gross' column by adding the two columns

movie_gross['total_gross'] = movie_gross['domestic_gross'] + movie_gross['foreign_gross']
movie_gross.head(10)
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
# 5                   The Twilight Saga: Eclipse   Sum.     300500000.0
# 6                                   Iron Man 2   Par.     312400000.0
# 7                                      Tangled     BV     200800000.0
# 8                                Despicable Me   Uni.     251500000.0
# 9                     How to Train Your Dragon   P/DW     217600000.0
#
#    foreign_gross  year   total_gross
# 0    652000000.0  2010  1.067000e+09
# 1    691300000.0  2010  1.025500e+09
# 2    664300000.0  2010  9.603000e+08
# 3    535700000.0  2010  8.283000e+08
# 4    513900000.0  2010  7.526000e+08
# 5    398000000.0  2010  6.985000e+08
# 6    311500000.0  2010  6.239000e+08
# 7    391000000.0  2010  5.918000e+08
# 8    291600000.0  2010  5.431000e+08
# 9    277300000.0  2010  4.949000e+08

# %%
top_20_rows_gross = movie_gross.nlargest(20, 'total_gross')
top_20_rows_gross
# Out:
#                                             title studio  domestic_gross  \
# 727                         Marvel's The Avengers     BV     623400000.0
# 1875                      Avengers: Age of Ultron     BV     459000000.0
# 3080                                Black Panther     BV     700100000.0
# 328   Harry Potter and the Deathly Hallows Part 2     WB     381000000.0
# 2758                     Star Wars: The Last Jedi     BV     620200000.0
# 3081               Jurassic World: Fallen Kingdom   Uni.     417700000.0
# 1127                                       Frozen     BV     400700000.0
# 2759                  Beauty and the Beast (2017)     BV     504000000.0
# 3082                                Incredibles 2     BV     608600000.0
# 1128                                   Iron Man 3     BV     409000000.0
# 1876                                      Minions   Uni.     336000000.0
# 2322                   Captain America: Civil War     BV     408100000.0
# 3083                                      Aquaman     WB     335100000.0
# 329                Transformers: Dark of the Moon   P/DW     352400000.0
# 728                                       Skyfall   Sony     304400000.0
# 1477              Transformers: Age of Extinction   Par.     245400000.0
# 729                         The Dark Knight Rises     WB     448100000.0
# 0                                     Toy Story 3     BV     415000000.0
# 2323                 Rogue One: A Star Wars Story     BV     532200000.0
# 330   Pirates of the Caribbean: On Stranger Tides     BV     241100000.0
#
#       foreign_gross  year   total_gross
# 727     895500000.0  2012  1.518900e+09
# 1875    946400000.0  2015  1.405400e+09
# 3080    646900000.0  2018  1.347000e+09
# 328     960500000.0  2011  1.341500e+09
# 2758    712400000.0  2017  1.332600e+09
# 3081    891800000.0  2018  1.309500e+09
# 1127    875700000.0  2013  1.276400e+09
# 2759    759500000.0  2017  1.263500e+09
# 3082    634200000.0  2018  1.242800e+09
# 1128    805800000.0  2013  1.214800e+09
# 1876    823400000.0  2015  1.159400e+09
# 2322    745200000.0  2016  1.153300e+09
# 3083    812700000.0  2018  1.147800e+09
# 329     771400000.0  2011  1.123800e+09
# 728     804200000.0  2012  1.108600e+09
# 1477    858600000.0  2014  1.104000e+09
# 729     636800000.0  2012  1.084900e+09
# 0       652000000.0  2010  1.067000e+09
# 2323    523900000.0  2016  1.056100e+09
# 330     804600000.0  2011  1.045700e+09

# %%
rows_with_nans = movie_gross[movie_gross.isnull().any(axis=1)]
print(rows_with_nans)
# Out:
#                                        title      studio  domestic_gross  \
# 210            Outside the Law (Hors-la-loi)         NaN         96900.0
# 222                                  Flipped          WB       1800000.0
# 230               It's a Wonderful Afterlife         UTV             NaN
# 254   The Polar Express (IMAX re-issue 2010)          WB        673000.0
# 267                           Tiny Furniture         IFC        392000.0
# ...                                      ...         ...             ...
# 3382                               The Quake       Magn.          6200.0
# 3383             Edward II (2018 re-release)          FM          4800.0
# 3384                                El Pacto        Sony          2500.0
# 3385                                The Swan  Synergetic          2400.0
# 3386                       An Actor Prepares       Grav.          1700.0
#
#       foreign_gross  year  total_gross
# 210       3300000.0  2010    3396900.0
# 222             NaN  2010          NaN
# 230       1300000.0  2010          NaN
# 254             NaN  2010          NaN
# 267             NaN  2010          NaN
# ...             ...   ...          ...
# 3382            NaN  2018          NaN
# 3383            NaN  2018          NaN
# 3384            NaN  2018          NaN
# 3385            NaN  2018          NaN
# 3386            NaN  2018          NaN
#
# [1385 rows x 6 columns]

# %%
movie_gross = movie_gross.dropna()

# %%
movie_info = pd.read_csv('zippedData/rt.movie_info.tsv.gz', delimiter='\t')

movie_info.head()
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# 2                   Allison Anders  Sep 13, 1996  Apr 18, 2000      NaN
# 3  Paul Attanasio|Michael Crichton   Dec 9, 1994  Aug 27, 1997      NaN
# 4                     Giles Cooper           NaN           NaN      NaN
#
#   box_office      runtime             studio
# 0        NaN  104 minutes                NaN
# 1    600,000  108 minutes  Entertainment One
# 2        NaN  116 minutes                NaN
# 3        NaN  128 minutes                NaN
# 4        NaN  200 minutes                NaN

# %%
# Replace 'zippedData/rt.reviews.tsv.gz' with the actual file path
file_path = 'zippedData/rt.reviews.tsv.gz'

# Read the TSV file into a Pandas DataFrame with 'latin1' encoding
reviews = pd.read_csv(file_path, delimiter='\t', encoding='latin1')

reviews.head()
# Out:
#    id                                             review rating   fresh  \
# 0   3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1   3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2   3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3   3  Continuing along a line introduced in last yea...    NaN   fresh
# 4   3             ... a perverse twist on neorealism...     NaN   fresh
#
#            critic  top_critic         publisher               date
# 0      PJ Nabarro           0   Patrick Nabarro  November 10, 2018
# 1  Annalee Newitz           0           io9.com       May 23, 2018
# 2    Sean Axmaker           0  Stream on Demand    January 4, 2018
# 3   Daniel Kasman           0              MUBI  November 16, 2017
# 4             NaN           0      Cinema Scope   October 12, 2017

# %%
reviews = reviews.dropna()

# %%
tmdb_movies = pd.read_csv('zippedData/tmdb.movies.csv.gz')

tmdb_movies.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %%
budgets = pd.read_csv('zippedData/tn.movie_budgets.csv.gz')

budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
conn = sqlite3.connect('zippedData/im.db')

# %%
query = "SELECT * FROM sqlite_master"

df = pd.read_sql(query, conn)

df.head()
# Out:
#     type           name       tbl_name  rootpage  \
# 0  table   movie_basics   movie_basics         2
# 1  table      directors      directors         3
# 2  table      known_for      known_for         4
# 3  table     movie_akas     movie_akas         5
# 4  table  movie_ratings  movie_ratings         6
#
#                                                  sql
# 0  CREATE TABLE "movie_basics" (\n"movie_id" TEXT...
# 1  CREATE TABLE "directors" (\n"movie_id" TEXT,\n...
# 2  CREATE TABLE "known_for" (\n"person_id" TEXT,\...
# 3  CREATE TABLE "movie_akas" (\n"movie_id" TEXT,\...
# 4  CREATE TABLE "movie_ratings" (\n"movie_id" TEX...

# %%
query = "SELECT * FROM sqlite_master"

df = pd.read_sql(query, conn)

df
# Out:
#     type           name       tbl_name  rootpage  \
# 0  table   movie_basics   movie_basics         2
# 1  table      directors      directors         3
# 2  table      known_for      known_for         4
# 3  table     movie_akas     movie_akas         5
# 4  table  movie_ratings  movie_ratings         6
# 5  table        persons        persons         7
# 6  table     principals     principals         8
# 7  table        writers        writers         9
#
#                                                  sql
# 0  CREATE TABLE "movie_basics" (\n"movie_id" TEXT...
# 1  CREATE TABLE "directors" (\n"movie_id" TEXT,\n...
# 2  CREATE TABLE "known_for" (\n"person_id" TEXT,\...
# 3  CREATE TABLE "movie_akas" (\n"movie_id" TEXT,\...
# 4  CREATE TABLE "movie_ratings" (\n"movie_id" TEX...
# 5  CREATE TABLE "persons" (\n"person_id" TEXT,\n ...
# 6  CREATE TABLE "principals" (\n"movie_id" TEXT,\...
# 7  CREATE TABLE "writers" (\n"movie_id" TEXT,\n  ...

# %%
def set_nulls_to_unknown(db_path):
    # Connect to the SQLite database
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()
    
    # Get the list of tables in the database
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
    tables = [table[0] for table in cursor.fetchall()]
    
    for table in tables:
        # Get columns of the table
        cursor.execute(f"PRAGMA table_info({table});")
        columns = [column[1] for column in cursor.fetchall()]  # index 1 is for the column name
        
        # Update each column setting NULL to 'unknown'
        for col in columns:
            cursor.execute(f"UPDATE {table} SET {col} = 'unknown' WHERE {col} IS NULL;")
        
        conn.commit()
    
    conn.close()

# Call the function with your SQLite database path
set_nulls_to_unknown('zippedData/im.db')

# %%
# Making sure the above code worked

def check_nulls(db_path):
    # Connect to the SQLite database
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()
    
    # Get the list of tables in the database
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
    tables = [table[0] for table in cursor.fetchall()]

    for table in tables:
        # Get columns of the table
        cursor.execute(f"PRAGMA table_info({table});")
        columns = [column[1] for column in cursor.fetchall()]

        # Check each column for NULL values
        for col in columns:
            cursor.execute(f"SELECT COUNT(*) FROM {table} WHERE {col} IS NULL;")
            null_count = cursor.fetchone()[0]
            
            if null_count > 0:
                print(f"Table '{table}', Column '{col}' has {null_count} NULL values.")
            else:
                print("No nulls, bestie!")
    
    conn.close()

# Call the function with your SQLite database path
check_nulls('zippedData/im.db')
# Out:
# No nulls, bestie!
# No nulls, bestie!
# No nulls, bestie!
# No nulls, bestie!
# No nulls, bestie!
# No nulls, bestie!
# No nulls, bestie!
# No nulls, bestie!
# No nulls, bestie!
# No nulls, bestie!
# No nulls, bestie!
# No nulls, bestie!
# No nulls, bestie!
# No nulls, bestie!
# No nulls, bestie!
# No nulls, bestie!
# No nulls, bestie!
# No nulls, bestie!
# No nulls, bestie!
# No nulls, bestie!
# No nulls, bestie!
# No nulls, bestie!
# No nulls, bestie!
# No nulls, bestie!
# No nulls, bestie!
# No nulls, bestie!
# No nulls, bestie!
# No nulls, bestie!
# No nulls, bestie!
# No nulls, bestie!
# No nulls, bestie!
# No nulls, bestie!
# No nulls, bestie!
# No nulls, bestie!

# %% [markdown]
# Now we'll go and clean specific tables.

# %% [markdown]
# # SQL

# %%
# %%bash
# sqlite3 zippedData/im.db
# .schema
# Out:
# CREATE TABLE IF NOT EXISTS "movie_basics" (
# "movie_id" TEXT,
#   "primary_title" TEXT,
#   "original_title" TEXT,
#   "start_year" INTEGER,
#   "runtime_minutes" REAL,
#   "genres" TEXT
# );
# CREATE TABLE IF NOT EXISTS "directors" (
# "movie_id" TEXT,
#   "person_id" TEXT
# );
# CREATE TABLE IF NOT EXISTS "known_for" (
# "person_id" TEXT,
#   "movie_id" TEXT
# );
# CREATE TABLE IF NOT EXISTS "movie_akas" (
# "movie_id" TEXT,
#   "ordering" INTEGER,
#   "title" TEXT,
#   "region" TEXT,
#   "language" TEXT,
#   "types" TEXT,
#   "attributes" TEXT,
#   "is_original_title" REAL
# );
# CREATE TABLE IF NOT EXISTS "movie_ratings" (
# "movie_id" TEXT,
#   "averagerating" REAL,
#   "numvotes" INTEGER
# );
# CREATE TABLE IF NOT EXISTS "persons" (
# "person_id" TEXT,
#   "primary_name" TEXT,
#   "birth_year" REAL,
#   "death_year" REAL,
#   "primary_profession" TEXT
# );
# CREATE TABLE IF NOT EXISTS "principals" (
# "movie_id" TEXT,
#   "ordering" INTEGER,
#   "person_id" TEXT,
#   "category" TEXT,
#   "job" TEXT,
#   "characters" TEXT
# );
# CREATE TABLE IF NOT EXISTS "writers" (
# "movie_id" TEXT,
#   "person_id" TEXT
# );

# %%
query = """
WITH HighlyRatedMovies AS (
    SELECT mr.movie_id
    FROM movie_ratings mr
    WHERE mr.averagerating > 8 and mr.numvotes >10000
),
ActorsInHighlyRatedMovies AS (
    SELECT kf.person_id, p.primary_name
    FROM known_for kf
    JOIN HighlyRatedMovies hrm ON kf.movie_id = hrm.movie_id
    JOIN persons p ON kf.person_id = p.person_id
)
SELECT primary_name, COUNT(*) as appearances
FROM ActorsInHighlyRatedMovies
GROUP BY primary_name
HAVING COUNT(*) > 1;
"""
best_actors = pd.read_sql(query, conn) 
best_actors
# Out:
#               primary_name  appearances
# 0            Aakash Dahiya            2
# 1         Aalaap Majgavkar            2
# 2             Aarif Sheikh            2
# 3              Aaron Lazar            3
# 4              Aarti Bajaj            2
# ..                     ...          ...
# 280        Vivek b Agrawal            2
# 281           Yogesh Soman            2
# 282            Zach Steele            2
# 283          Zakir Hussain            2
# 284  Zeynep Ozbatur Atakan            2
#
# [285 rows x 2 columns]

# %%
query = """
WITH HighlyRatedMovies AS (
    SELECT mr.movie_id
    FROM movie_ratings mr
    WHERE mr.averagerating > 8 and mr.numvotes >10000
),
ActorsInHighlyRatedMovies AS (
    SELECT kf.person_id, p.primary_name
    FROM known_for kf
    JOIN HighlyRatedMovies hrm ON kf.movie_id = hrm.movie_id
    JOIN persons p ON kf.person_id = p.person_id
)
SELECT primary_name, COUNT(*) as appearances
FROM ActorsInHighlyRatedMovies
GROUP BY primary_name
HAVING COUNT(*) > 1;
"""
best_actors = pd.read_sql(query, conn) 
best_actors
# Out:
#               primary_name  appearances
# 0            Aakash Dahiya            2
# 1         Aalaap Majgavkar            2
# 2             Aarif Sheikh            2
# 3              Aaron Lazar            3
# 4              Aarti Bajaj            2
# ..                     ...          ...
# 280        Vivek b Agrawal            2
# 281           Yogesh Soman            2
# 282            Zach Steele            2
# 283          Zakir Hussain            2
# 284  Zeynep Ozbatur Atakan            2
#
# [285 rows x 2 columns]

# %%
best_actors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 285 entries, 0 to 284
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   primary_name  285 non-null    object
#  1   appearances   285 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 4.6+ KB

# %%
best_actors= best_actors.sort_values(by='appearances', ascending=True)

# %%
best_actors
# Out:
#          primary_name  appearances
# 0       Aakash Dahiya            2
# 172    Nathan Santell            2
# 173    Neeraj Ghaywan            2
# 175  Nicholas D. Ward            2
# 176    Nicholas Simon            2
# ..                ...          ...
# 263         Tom Hardy            3
# 59       Daler Mehndi            3
# 236    Shishir Sharma            3
# 18       Amit Trivedi            3
# 128       Ketan Sodha            4
#
# [285 rows x 2 columns]

# %%
best_actor_series = best_actors.set_index('primary_name')['appearances']

# %%
best_actor_series[best_actor_series == best_actor_series.max()]
# Out:
# primary_name
# Ketan Sodha    4
# Name: appearances, dtype: int64

# %%
best_actors.tail(5)
# Out:
#        primary_name  appearances
# 263       Tom Hardy            3
# 59     Daler Mehndi            3
# 236  Shishir Sharma            3
# 18     Amit Trivedi            3
# 128     Ketan Sodha            4

# %%
import matplotlib.pyplot as plt
# Sort the DataFrame by 'appearances' in descending order to get the top actors at the top
best_actors_sorted = best_actors.sort_values(by='appearances', ascending=False)
# Plotting the bar graph
plt.figure(figsize=(10, 8)) # Adjust the figure size based on the number of actors 
best_actors_sorted.head(10).plot(x='primary_name', y='appearances', kind='bar', legend=False)
plt.title('Top Actors in Highly-Rated Movies')
plt.ylabel('Number of Appearances')
plt.xlabel('Name')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Budgets

# %%
budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
budgets['production_budget'] = budgets['production_budget'].str.replace('[$,]', '', regex=True).astype(float)

# %%
budgets['domestic_gross'] = budgets['domestic_gross'].str.replace('[$,]', '', regex=True).astype(float)

# %%
budgets['worldwide_gross'] = budgets['worldwide_gross'].str.replace('[$,]', '', regex=True).astype(float)

# %%
budgets['release_date'] = pd.to_datetime(budgets['release_date'], format='%b %d, %Y')

# %%
budgets['production_budget'] = pd.to_numeric(budgets['production_budget'], errors='coerce')

print(budgets.head())
# Out:
#    id release_date                                        movie  \
# 0   1   2009-12-18                                       Avatar
# 1   2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   3   2019-06-07                                 Dark Phoenix
# 3   4   2015-05-01                      Avengers: Age of Ultron
# 4   5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross
# 0        425000000.0     760507625.0     2.776345e+09
# 1        410600000.0     241063875.0     1.045664e+09
# 2        350000000.0      42762350.0     1.497624e+08
# 3        330600000.0     459005868.0     1.403014e+09
# 4        317000000.0     620181382.0     1.316722e+09

# %%
movie_info_sorted_by_bred = budgets.sort_values(by='production_budget', ascending=True)

movie_info_sorted_by_bred.reset_index(drop=True, inplace=True)
movie_info_sorted_by_bred.head()
# Out:
#    id release_date                          movie  production_budget  \
# 0  82   2005-08-05              My Date With Drew             1100.0
# 1  81   2015-09-29           A Plague So Pleasant             1400.0
# 2  80   2005-07-13  Return to the Land of Wonders             5000.0
# 3  79   1999-04-02                      Following             6000.0
# 4  77   2004-12-31                The Mongol King             7000.0
#
#    domestic_gross  worldwide_gross
# 0        181041.0         181041.0
# 1             0.0              0.0
# 2          1338.0           1338.0
# 3         48482.0         240495.0
# 4           900.0            900.0

# %%
movie_info_sorted_by_date = budgets.sort_values(by='release_date', ascending=True)

movie_info_sorted_by_date.reset_index(drop=True, inplace=True)
movie_info_sorted_by_date.tail()
# Out:
#       id release_date                   movie  production_budget  \
# 5777  30   2019-12-31                  Reagan         25000000.0
# 5778  13   2019-12-31              Rogue City         13000000.0
# 5779  36   2020-02-21        Call of the Wild         82000000.0
# 5780   6   2020-12-31  Hannibal the Conqueror         50000000.0
# 5781  95   2020-12-31                Moonfall        150000000.0
#
#       domestic_gross  worldwide_gross
# 5777             0.0              0.0
# 5778             0.0              0.0
# 5779             0.0              0.0
# 5780             0.0              0.0
# 5781             0.0              0.0

# %%
movie_info_sorted_by_world = budgets.sort_values(by='worldwide_gross', ascending=True)

movie_info_sorted_by_world.reset_index(drop=True, inplace=True)
movie_info_sorted_by_world.head()
# Out:
#    id release_date                                    movie  \
# 0  38   2019-04-23  Living Dark: The Story of Ted the Caver
# 1  76   2015-05-15                           Pound of Flesh
# 2  28   2011-06-28                                     2:13
# 3  29   2013-01-29  Batman: The Dark Knight Returns, Part 2
# 4  48   2019-06-21                           Burn Your Maps
#
#    production_budget  domestic_gross  worldwide_gross
# 0          1750000.0             0.0              0.0
# 1          7500000.0             0.0              0.0
# 2          3500000.0             0.0              0.0
# 3          3500000.0             0.0              0.0
# 4          8000000.0             0.0              0.0

# %%
budgets.describe()
# Out:
#                 id                   release_date  production_budget  \
# count  5782.000000                           5782       5.782000e+03
# mean     50.372363  2004-07-06 05:20:31.546177792       3.158776e+07
# min       1.000000            1915-02-08 00:00:00       1.100000e+03
# 25%      25.000000            2000-04-22 18:00:00       5.000000e+06
# 50%      50.000000            2007-03-02 00:00:00       1.700000e+07
# 75%      75.000000            2012-12-25 00:00:00       4.000000e+07
# max     100.000000            2020-12-31 00:00:00       4.250000e+08
# std      28.821076                            NaN       4.181208e+07
#
#        domestic_gross  worldwide_gross
# count    5.782000e+03     5.782000e+03
# mean     4.187333e+07     9.148746e+07
# min      0.000000e+00     0.000000e+00
# 25%      1.429534e+06     4.125415e+06
# 50%      1.722594e+07     2.798445e+07
# 75%      5.234866e+07     9.764584e+07
# max      9.366622e+08     2.776345e+09
# std      6.824060e+07     1.747200e+08

# %%
# fig, ax = plt.subplots()
# top_ten_gross_data[['domestic_gross', 'worldwide_gross']].plot(kind='bar', ax=ax)

# ax.set_title('Comparison of Top Ten Domestic Gross and Worldwide Gross')
# plt.tight_layout()

movie_info_sorted = budgets.sort_values(by=['domestic_gross', 'worldwide_gross'], ascending=False)
top_ten_gross_data = movie_info_sorted.head(6)

# %%
pg_df = top_ten_gross_data[['movie','domestic_gross', 'worldwide_gross']].set_index('movie')

# %%
fig, ax = plt.subplots(figsize = (10,12))
pg_df[['domestic_gross', 'worldwide_gross']].plot(kind='bar', ax=ax)

ax.set_title('Comparison of Top Ten Domestic Gross and Worldwide Gross')
plt.tight_layout()

# %% [markdown]
# Cleaning the next table

# %% [markdown]
# # TMBD movies

# %%
tmdb_movies.describe()
# Out:
#         Unnamed: 0             id    popularity  vote_average    vote_count
# count  26517.00000   26517.000000  26517.000000  26517.000000  26517.000000
# mean   13258.00000  295050.153260      3.130912      5.991281    194.224837
# std     7654.94288  153661.615648      4.355229      1.852946    960.961095
# min        0.00000      27.000000      0.600000      0.000000      1.000000
# 25%     6629.00000  157851.000000      0.600000      5.000000      2.000000
# 50%    13258.00000  309581.000000      1.374000      6.000000      5.000000
# 75%    19887.00000  419542.000000      3.694000      7.000000     28.000000
# max    26516.00000  608444.000000     80.773000     10.000000  22186.000000

# %%
tmdb_movies.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %%
null_counts = tmdb_movies.isnull().sum()
null_counts
# Out:
# Unnamed: 0           0
# genre_ids            0
# id                   0
# original_language    0
# original_title       0
# popularity           0
# release_date         0
# title                0
# vote_average         0
# vote_count           0
# dtype: int64

# %%
pop = tmdb_movies.sort_values(by='popularity', ascending=True)

pop.reset_index(drop=True, inplace=True)
pop.tail()
# Out:
#        Unnamed: 0              genre_ids      id original_language  \
# 26512        5179          [878, 28, 12]   24428                en
# 26513       11020           [28, 12, 14]  122917                en
# 26514       23812  [28, 12, 16, 878, 35]  324857                en
# 26515       11019               [28, 53]  245891                en
# 26516       23811           [12, 28, 14]  299536                en
#
#                                   original_title  popularity release_date  \
# 26512                               The Avengers      50.289   2012-05-04
# 26513  The Hobbit: The Battle of the Five Armies      53.783   2014-12-17
# 26514          Spider-Man: Into the Spider-Verse      60.534   2018-12-14
# 26515                                  John Wick      78.123   2014-10-24
# 26516                     Avengers: Infinity War      80.773   2018-04-27
#
#                                            title  vote_average  vote_count
# 26512                               The Avengers           7.6       19673
# 26513  The Hobbit: The Battle of the Five Armies           7.3        8392
# 26514          Spider-Man: Into the Spider-Verse           8.4        4048
# 26515                                  John Wick           7.2       10081
# 26516                     Avengers: Infinity War           8.3       13948

# %%
vote = tmdb_movies.sort_values(by='vote_count', ascending=True)

vote.reset_index(drop=True, inplace=True)
vote.head(20)
# Out:
#     Unnamed: 0           genre_ids      id original_language  \
# 0        13258                [99]  403294                en
# 1        13386                  []  493666                en
# 2        13387         [10402, 35]  477565                en
# 3        13389        [99, 18, 53]  464296                en
# 4        13390         [99, 10402]  456923                en
# 5        13392  [18, 10402, 10770]  431039                vi
# 6        13394           [878, 18]  428930                en
# 7        13395                  []  424817                en
# 8        13385        [14, 53, 36]  498113                en
# 9        13396                  []  424812                en
# 10       13400                  []  393082                en
# 11       13401                [99]  391136                en
# 12       13403           [18, 878]  385129                en
# 13       13404                  []  375083                en
# 14       13405           [18, 878]  367531                en
# 15       13407                  []  359703                en
# 16       13410            [36, 99]  346104                en
# 17       13399                  []  409486                en
# 18       13384            [16, 14]  523644                en
# 19       13383                  []  572524                en
#
#                                        original_title  popularity  \
# 0                                   9/11: Simulations         0.6
# 1                 Addiction: This Is Not a Love Story         0.6
# 2                                            Batmetal         0.6
# 3                                       Vegas Vikings         0.6
# 4   Rise of a Texas Bluesman: Stevie Ray Vaughan 1...         0.6
# 5                                  Paris by night 112         0.6
# 6                                               Drink         0.6
# 7                                     Chestnut Street         0.6
# 8                                     Afflicted, Inc.         0.6
# 9                           Emulsion Electrons Imbued         0.6
# 10                                           The Hunt         0.6
# 11                                     Inside Her Sex         0.6
# 12                                               Test         0.6
# 13                        Sufferfest 2: Desert Alpine         0.6
# 14                                                NEW         0.6
# 15                                         Barbie Boy         0.6
# 16                         Faberge: A Life of Its Own         0.6
# 17  Sabrina: Secrets of a Teenage Witch - A Witch ...         0.6
# 18                                               Lake         0.6
# 19                         When God Left the Building         0.6
#
#    release_date                                              title  \
# 0    2014-07-04                                  9/11: Simulations
# 1    2014-11-20                Addiction: This Is Not a Love Story
# 2    2014-01-07                                           Batmetal
# 3    2014-12-06                                      Vegas Vikings
# 4    2014-09-09  Rise of a Texas Bluesman: Stevie Ray Vaughan 1...
# 5    2014-12-21                                 Paris by night 112
# 6    2014-01-01                                              Drink
# 7    2014-01-01                                    Chestnut Street
# 8    2014-03-24                                    Afflicted, Inc.
# 9    2014-01-01                          Emulsion Electrons Imbued
# 10   2014-10-04                                           The Hunt
# 11   2014-11-30                                     Inside Her Sex
# 12   2014-09-27                                               Test
# 13   2014-11-13                        Sufferfest 2: Desert Alpine
# 14   2014-12-04                                                NEW
# 15   2014-11-14                                         Barbie Boy
# 16   2014-04-04                         Faberge: A Life of Its Own
# 17   2014-09-01  Sabrina: Secrets of a Teenage Witch - A Witch ...
# 18   2014-02-11                                               Lake
# 19   2014-01-01                         When God Left the Building
#
#     vote_average  vote_count
# 0           10.0           1
# 1            8.0           1
# 2            8.0           1
# 3            8.0           1
# 4            8.0           1
# 5            8.0           1
# 6            8.0           1
# 7            8.0           1
# 8            8.0           1
# 9            8.0           1
# 10           8.0           1
# 11           8.0           1
# 12           8.0           1
# 13           8.0           1
# 14           8.0           1
# 15           8.0           1
# 16           8.0           1
# 17           8.0           1
# 18           8.0           1
# 19           8.0           1

# %%
tmdb_movies.describe()
# Out:
#         Unnamed: 0             id    popularity  vote_average    vote_count
# count  26517.00000   26517.000000  26517.000000  26517.000000  26517.000000
# mean   13258.00000  295050.153260      3.130912      5.991281    194.224837
# std     7654.94288  153661.615648      4.355229      1.852946    960.961095
# min        0.00000      27.000000      0.600000      0.000000      1.000000
# 25%     6629.00000  157851.000000      0.600000      5.000000      2.000000
# 50%    13258.00000  309581.000000      1.374000      6.000000      5.000000
# 75%    19887.00000  419542.000000      3.694000      7.000000     28.000000
# max    26516.00000  608444.000000     80.773000     10.000000  22186.000000

# %%
tmdb_movies['vote_count'].median()
# Out:
# 5.0

# %%
filtered_movies = tmdb_movies[(tmdb_movies['vote_count'] > 1000) & (tmdb_movies['original_language'] == 'en')]

# Sort the filtered DataFrame by 'vote_average' in descending order and take the top 10
top_10_movies = filtered_movies.nlargest(10, 'vote_average')

# Create a bar plot for the top 10 movies
plt.figure(figsize=(12, 6))
plt.barh(top_10_movies['original_title'], top_10_movies['vote_average'], color='skyblue')
plt.xlabel('Vote Average')
plt.ylabel('Movie Title')
plt.title('Top 10 Movies by Vote Average (Vote Count > 1000)')
plt.gca().invert_yaxis()  # Invert the y-axis to show the highest vote_average at the top
plt.show()

# %%
filtered_movies = tmdb_movies[tmdb_movies['vote_count'] > 1000 & (tmdb_movies['original_language'] == 'en')]
filtered_movies
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# 3                                         Toy Story      28.005   1995-11-22
# 4                                         Inception      27.920   2010-07-16
# ...                                             ...         ...          ...
# 26512                         Laboratory Conditions       0.600   2018-10-13
# 26513                               _EXHIBIT_84xxx_       0.600   2018-05-01
# 26514                                  The Last One       0.600   2018-10-01
# 26515                                  Trailer Made       0.600   2018-06-22
# 26516                                    The Church       0.600   2018-10-05
#
#                                               title  vote_average  vote_count
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                          How to Train Your Dragon           7.7        7610
# 2                                        Iron Man 2           6.8       12368
# 3                                         Toy Story           7.9       10174
# 4                                         Inception           8.3       22186
# ...                                             ...           ...         ...
# 26512                         Laboratory Conditions           0.0           1
# 26513                               _EXHIBIT_84xxx_           0.0           1
# 26514                                  The Last One           0.0           1
# 26515                                  Trailer Made           0.0           1
# 26516                                    The Church           0.0           1
#
# [26517 rows x 10 columns]

# %% [markdown]
# Cleaning another data set below

# %% [markdown]
# # Movie info

# %%
movie_info['currency'].fillna('$', inplace=True)

movie_info.head()
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001        $
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# 2                   Allison Anders  Sep 13, 1996  Apr 18, 2000        $
# 3  Paul Attanasio|Michael Crichton   Dec 9, 1994  Aug 27, 1997        $
# 4                     Giles Cooper           NaN           NaN        $
#
#   box_office      runtime             studio
# 0        NaN  104 minutes                NaN
# 1    600,000  108 minutes  Entertainment One
# 2        NaN  116 minutes                NaN
# 3        NaN  128 minutes                NaN
# 4        NaN  200 minutes                NaN

# %%
movie_info_cleaned = movie_info.dropna(subset=['genre', 'rating'])

movie_info_cleaned.reset_index(drop=True, inplace=True)
movie_info_cleaned.head()
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001        $
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# 2                   Allison Anders  Sep 13, 1996  Apr 18, 2000        $
# 3  Paul Attanasio|Michael Crichton   Dec 9, 1994  Aug 27, 1997        $
# 4                     Giles Cooper           NaN           NaN        $
#
#   box_office      runtime             studio
# 0        NaN  104 minutes                NaN
# 1    600,000  108 minutes  Entertainment One
# 2        NaN  116 minutes                NaN
# 3        NaN  128 minutes                NaN
# 4        NaN  200 minutes                NaN

# %%
movie_info_cleaned['dvd_date'] = pd.to_datetime(movie_info_cleaned['dvd_date'], format='%b %d, %Y')
# Out:
# /var/folders/1f/98thg_p17ml4vwvv3m9xpp380000gn/T/ipykernel_23312/3006772974.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_info_cleaned['dvd_date'] = pd.to_datetime(movie_info_cleaned['dvd_date'], format='%b %d, %Y')

# %%
movie_info_cleaned['theater_date'] = pd.to_datetime(movie_info_cleaned['theater_date'], format='%b %d, %Y')
# Out:
# /var/folders/1f/98thg_p17ml4vwvv3m9xpp380000gn/T/ipykernel_23312/3503527468.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_info_cleaned['theater_date'] = pd.to_datetime(movie_info_cleaned['theater_date'], format='%b %d, %Y')

# %%
movie_info_cleaned.isnull().sum()
# Out:
# id                 0
# synopsis          57
# rating             0
# genre              0
# director         192
# writer           442
# theater_date     351
# dvd_date         351
# currency           0
# box_office      1212
# runtime           26
# studio          1058
# dtype: int64

# %%
movie_info_cleaned.head()
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer theater_date   dvd_date currency  \
# 0                   Ernest Tidyman   1971-10-09 2001-09-25        $
# 1     David Cronenberg|Don DeLillo   2012-08-17 2013-01-01        $
# 2                   Allison Anders   1996-09-13 2000-04-18        $
# 3  Paul Attanasio|Michael Crichton   1994-12-09 1997-08-27        $
# 4                     Giles Cooper          NaT        NaT        $
#
#   box_office      runtime             studio
# 0        NaN  104 minutes                NaN
# 1    600,000  108 minutes  Entertainment One
# 2        NaN  116 minutes                NaN
# 3        NaN  128 minutes                NaN
# 4        NaN  200 minutes                NaN

# %%
movie_info_cleaned['dvd_date'].min()
# Out:
# Timestamp('1987-04-15 00:00:00')

# %%
movie_info_cleaned.loc[10]
# Out:
# id                                                             18
# synopsis        In 1979, Bill Viola and Frank Caliguri dreamed...
# rating                                                         NR
# genre                                                 Documentary
# director                                                      NaN
# writer                                               Robert Zullo
# theater_date                                                  NaT
# dvd_date                                                      NaT
# currency                                                        $
# box_office                                                    NaN
# runtime                                                       NaN
# studio                                 Showtime Documentary Films
# Name: 10, dtype: object

# %%
movie_info_cleaned.head(12)
# Out:
#     id                                           synopsis rating  \
# 0    1  This gritty, fast-paced, and innovative police...      R
# 1    3  New York City, not-too-distant-future: Eric Pa...      R
# 2    5  Illeana Douglas delivers a superb performance ...      R
# 3    6  Michael Douglas runs afoul of a treacherous su...      R
# 4    7                                                NaN     NR
# 5    8  The year is 1942. As the Allies unite overseas...     PG
# 6   10  Some cast and crew from NBC's highly acclaimed...  PG-13
# 7   13  Stewart Kane, an Irishman living in the Austra...      R
# 8   14  "Love Ranch" is a bittersweet love story that ...      R
# 9   15  When a diamond expedition in the Congo is lost...  PG-13
# 10  18  In 1979, Bill Viola and Frank Caliguri dreamed...     NR
# 11  19  While Microsoft may be the biggest software co...     NR
#
#                                                 genre          director  \
# 0                 Action and Adventure|Classics|Drama  William Friedkin
# 1                   Drama|Science Fiction and Fantasy  David Cronenberg
# 2                   Drama|Musical and Performing Arts    Allison Anders
# 3                          Drama|Mystery and Suspense    Barry Levinson
# 4                                       Drama|Romance    Rodney Bennett
# 5                               Drama|Kids and Family       Jay Russell
# 6                                              Comedy       Jake Kasdan
# 7                                               Drama      Ray Lawrence
# 8                                               Drama   Taylor Hackford
# 9   Action and Adventure|Mystery and Suspense|Scie...    Frank Marshall
# 10                                        Documentary               NaN
# 11                       Documentary|Special Interest               NaN
#
#                               writer theater_date   dvd_date currency  \
# 0                     Ernest Tidyman   1971-10-09 2001-09-25        $
# 1       David Cronenberg|Don DeLillo   2012-08-17 2013-01-01        $
# 2                     Allison Anders   1996-09-13 2000-04-18        $
# 3    Paul Attanasio|Michael Crichton   1994-12-09 1997-08-27        $
# 4                       Giles Cooper          NaT        NaT        $
# 5                    Gail Gilchriest   2000-03-03 2000-07-11        $
# 6                         Mike White   2002-01-11 2002-06-18        $
# 7   Raymond Carver|Beatrix Christian   2006-04-27 2007-10-02        $
# 8                      Mark Jacobson   2010-06-30 2010-11-09        $
# 9               John Patrick Shanley   1995-06-09 1999-07-27        $
# 10                      Robert Zullo          NaT        NaT        $
# 11                               NaN   2002-08-23 2003-09-30        $
#
#     box_office      runtime                      studio
# 0          NaN  104 minutes                         NaN
# 1      600,000  108 minutes           Entertainment One
# 2          NaN  116 minutes                         NaN
# 3          NaN  128 minutes                         NaN
# 4          NaN  200 minutes                         NaN
# 5          NaN   95 minutes       Warner Bros. Pictures
# 6   41,032,915   82 minutes          Paramount Pictures
# 7      224,114  123 minutes      Sony Pictures Classics
# 8      134,904  117 minutes                         NaN
# 9          NaN  108 minutes                         NaN
# 10         NaN          NaN  Showtime Documentary Films
# 11         NaN   90 minutes       Seventh Art Releasing

# %%
movie_info_cleaned['dvd_date'].max()
# Out:
# Timestamp('2019-02-05 00:00:00')

# %%
movie_info_cleaned.loc[10, 'director'] = 'Henry Roosevelt, W.B. Zullo'

# %%
movie_info_cleaned.loc[1125, 'synopsis'] = 'Knock Off'

# %%
movie_info_cleaned['genre'].value_counts().head(20)
# Out:
# genre
# Drama                                               151
# Comedy                                              110
# Comedy|Drama                                         80
# Drama|Mystery and Suspense                           67
# Art House and International|Drama                    62
# Action and Adventure|Drama                           42
# Action and Adventure|Drama|Mystery and Suspense      40
# Drama|Romance                                        35
# Comedy|Romance                                       32
# Art House and International|Comedy|Drama             31
# Horror                                               31
# Action and Adventure|Science Fiction and Fantasy     24
# Comedy|Drama|Romance                                 23
# Classics|Drama                                       21
# Action and Adventure|Mystery and Suspense            20
# Action and Adventure                                 19
# Classics|Drama|Mystery and Suspense                  18
# Horror|Mystery and Suspense                          17
# Documentary|Special Interest                         14
# Drama|Musical and Performing Arts                    14
# Name: count, dtype: int64

# %%
drama_movies = movie_info_cleaned[movie_info_cleaned['genre'].str.contains('drama', case=False)]
drama_movies
# Out:
#         id                                           synopsis rating  \
# 0        1  This gritty, fast-paced, and innovative police...      R
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 2        5  Illeana Douglas delivers a superb performance ...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 4        7                                                NaN     NR
# ...    ...                                                ...    ...
# 1543  1991  Popular rap group Run DMC stars as a trio of p...      R
# 1544  1992  The title character, played by John Turturro, ...      R
# 1549  1998  Based on a novel by Richard Powell, when the l...      G
# 1550  1999  The Sandlot is a coming-of-age story about a g...     PG
# 1551  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                   genre            director  \
# 0                   Action and Adventure|Classics|Drama    William Friedkin
# 1                     Drama|Science Fiction and Fantasy    David Cronenberg
# 2                     Drama|Musical and Performing Arts      Allison Anders
# 3                            Drama|Mystery and Suspense      Barry Levinson
# 4                                         Drama|Romance      Rodney Bennett
# ...                                                 ...                 ...
# 1543                         Action and Adventure|Drama          Rick Rubin
# 1544                                       Comedy|Drama           Joel Coen
# 1549  Classics|Comedy|Drama|Musical and Performing Arts      Gordon Douglas
# 1550    Comedy|Drama|Kids and Family|Sports and Fitness  David Mickey Evans
# 1551  Action and Adventure|Art House and Internation...                 NaN
#
#                                 writer theater_date   dvd_date currency  \
# 0                       Ernest Tidyman   1971-10-09 2001-09-25        $
# 1         David Cronenberg|Don DeLillo   2012-08-17 2013-01-01        $
# 2                       Allison Anders   1996-09-13 2000-04-18        $
# 3      Paul Attanasio|Michael Crichton   1994-12-09 1997-08-27        $
# 4                         Giles Cooper          NaT        NaT        $
# ...                                ...          ...        ...      ...
# 1543            Rick Rubin|Ric Menello          NaT        NaT        $
# 1544              Joel Coen|Ethan Coen   1991-08-21 2003-05-20        $
# 1549                               NaN   1962-01-01 2004-05-11        $
# 1550  David Mickey Evans|Robert Gunter   1993-04-01 2002-01-29        $
# 1551                        Luc Besson   2001-09-27 2003-02-11        $
#
#      box_office      runtime             studio
# 0           NaN  104 minutes                NaN
# 1       600,000  108 minutes  Entertainment One
# 2           NaN  116 minutes                NaN
# 3           NaN  128 minutes                NaN
# 4           NaN  200 minutes                NaN
# ...         ...          ...                ...
# 1543        NaN   92 minutes                NaN
# 1544        NaN  116 minutes                NaN
# 1549        NaN  111 minutes                NaN
# 1550        NaN  101 minutes                NaN
# 1551        NaN   94 minutes  Columbia Pictures
#
# [912 rows x 12 columns]

# %%
movie_info_cleaned.sort_values(by='synopsis', ascending=True)
# Out:
#         id                                           synopsis rating  \
# 676    871  "Another basement, another elevator...how can ...      R
# 450    596  "Arctic Tale" is an epic adventure that explor...      G
# 1417  1837  "Becoming Jane," is the story of the great, un...     PG
# 1454  1881  "Bicentennial Man," follows the life and times...     PG
# 66      85  "Boys Town" goes to turn-of-the-century St. Lo...     NR
# ...    ...                                                ...    ...
# 1309  1700                                                NaN     NR
# 1335  1735                                                NaN     NR
# 1362  1768                                                NaN     NR
# 1405  1821                                                NaN     NR
# 1480  1913                                                NaN     NR
#
#                                           genre                      director  \
# 676   Action and Adventure|Mystery and Suspense                  Renny Harlin
# 450                Documentary|Special Interest  Adam Ravetch|Sarah Robertson
# 1417                              Drama|Romance                Julian Jarrold
# 1454   Comedy|Drama|Science Fiction and Fantasy                Chris Columbus
# 66                                        Drama                  Ted Tetzlaff
# ...                                         ...                           ...
# 1309                                      Drama                        Loc Do
# 1335          Art House and International|Drama                  Alain Tanner
# 1362                                Documentary               Lina Mannheimer
# 1405   Art House and International|Comedy|Drama              Roman Bondarchuk
# 1480                       Action and Adventure                           NaN
#
#                                            writer theater_date   dvd_date  \
# 676                                           NaN   1990-07-02 1999-03-09
# 450   Linda Woolverton|Mose Richards|Kristin Gore   2007-08-17 2017-08-01
# 1417                    Sarah Williams|Kevin Hood   2007-08-03 2008-02-12
# 1454                               Nicholas Kazan   1999-12-17 2002-01-15
# 66                      Martin Rackin|Frank Davis          NaT        NaT
# ...                                           ...          ...        ...
# 1309                                          NaN          NaT        NaT
# 1335                                 Alain Tanner   1983-01-01 1992-07-15
# 1362                                          NaN          NaT        NaT
# 1405                                          NaN          NaT        NaT
# 1480                                          NaN          NaT        NaT
#
#      currency  box_office      runtime                studio
# 676         $         NaN  124 minutes                   NaN
# 450         $     598,103   86 minutes     Paramount Vantage
# 1417        $  18,602,895  120 minutes         Miramax Films
# 1454        $         NaN  131 minutes  Buena Vista Pictures
# 66          $         NaN   92 minutes                   NaN
# ...       ...         ...          ...                   ...
# 1309        $         NaN  119 minutes                   NaN
# 1335        $         NaN  108 minutes                   NaN
# 1362        $         NaN          NaN                   NaN
# 1405        $         NaN          NaN                   NaN
# 1480        $         NaN          NaN                   NaN
#
# [1552 rows x 12 columns]

# %%
movie_info_cleaned.shape
# Out:
# (1552, 12)

# %%
movie_info_cleaned = movie_info_cleaned.dropna(subset=['runtime'])

# %%
movie_info_cleaned = movie_info_cleaned.dropna(subset=['synopsis'])

# %%
movie_info_cleaned = movie_info_cleaned.dropna(subset=['dvd_date'])

# %%
movie_info_cleaned.isnull().sum()
# Out:
# id                0
# synopsis          0
# rating            0
# genre             0
# director        118
# writer          263
# theater_date      0
# dvd_date          0
# currency          0
# box_office      859
# runtime           0
# studio          731
# dtype: int64

# %%
movie_info_cleaned
# Out:
#         id                                           synopsis rating  \
# 0        1  This gritty, fast-paced, and innovative police...      R
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 2        5  Illeana Douglas delivers a superb performance ...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 5        8  The year is 1942. As the Allies unite overseas...     PG
# ...    ...                                                ...    ...
# 1547  1996  Forget terrorists or hijackers -- there's a ha...      R
# 1548  1997  The popular Saturday Night Live sketch was exp...     PG
# 1549  1998  Based on a novel by Richard Powell, when the l...      G
# 1550  1999  The Sandlot is a coming-of-age story about a g...     PG
# 1551  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                   genre            director  \
# 0                   Action and Adventure|Classics|Drama    William Friedkin
# 1                     Drama|Science Fiction and Fantasy    David Cronenberg
# 2                     Drama|Musical and Performing Arts      Allison Anders
# 3                            Drama|Mystery and Suspense      Barry Levinson
# 5                                 Drama|Kids and Family         Jay Russell
# ...                                                 ...                 ...
# 1547   Action and Adventure|Horror|Mystery and Suspense                 NaN
# 1548                 Comedy|Science Fiction and Fantasy        Steve Barron
# 1549  Classics|Comedy|Drama|Musical and Performing Arts      Gordon Douglas
# 1550    Comedy|Drama|Kids and Family|Sports and Fitness  David Mickey Evans
# 1551  Action and Adventure|Art House and Internation...                 NaN
#
#                                                 writer theater_date  \
# 0                                       Ernest Tidyman   1971-10-09
# 1                         David Cronenberg|Don DeLillo   2012-08-17
# 2                                       Allison Anders   1996-09-13
# 3                      Paul Attanasio|Michael Crichton   1994-12-09
# 5                                      Gail Gilchriest   2000-03-03
# ...                                                ...          ...
# 1547                                               NaN   2006-08-18
# 1548  Terry Turner|Tom Davis|Dan Aykroyd|Bonnie Turner   1993-07-23
# 1549                                               NaN   1962-01-01
# 1550                  David Mickey Evans|Robert Gunter   1993-04-01
# 1551                                        Luc Besson   2001-09-27
#
#        dvd_date currency  box_office      runtime                 studio
# 0    2001-09-25        $         NaN  104 minutes                    NaN
# 1    2013-01-01        $     600,000  108 minutes      Entertainment One
# 2    2000-04-18        $         NaN  116 minutes                    NaN
# 3    1997-08-27        $         NaN  128 minutes                    NaN
# 5    2000-07-11        $         NaN   95 minutes  Warner Bros. Pictures
# ...         ...      ...         ...          ...                    ...
# 1547 2007-01-02        $  33,886,034  106 minutes        New Line Cinema
# 1548 2001-04-17        $         NaN   88 minutes      Paramount Vantage
# 1549 2004-05-11        $         NaN  111 minutes                    NaN
# 1550 2002-01-29        $         NaN  101 minutes                    NaN
# 1551 2003-02-11        $         NaN   94 minutes      Columbia Pictures
#
# [1191 rows x 12 columns]

# %%
movie_info_cleaned.loc[1123, 'synopsis'] = 'Liliom'

# %%
movie_info_cleaned.loc[1126, 'synopsis'] = 'The Blade'

# %%
movie_info_cleaned.loc[1335, 'synopsis'] = 'In The White City'

# %% [markdown]
# Adding the data sets together and limiting the data down to common those who have common values.

# %% [markdown]
# # Combined DF

# %%
tmdb_movies
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# 3                                         Toy Story      28.005   1995-11-22
# 4                                         Inception      27.920   2010-07-16
# ...                                             ...         ...          ...
# 26512                         Laboratory Conditions       0.600   2018-10-13
# 26513                               _EXHIBIT_84xxx_       0.600   2018-05-01
# 26514                                  The Last One       0.600   2018-10-01
# 26515                                  Trailer Made       0.600   2018-06-22
# 26516                                    The Church       0.600   2018-10-05
#
#                                               title  vote_average  vote_count
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                          How to Train Your Dragon           7.7        7610
# 2                                        Iron Man 2           6.8       12368
# 3                                         Toy Story           7.9       10174
# 4                                         Inception           8.3       22186
# ...                                             ...           ...         ...
# 26512                         Laboratory Conditions           0.0           1
# 26513                               _EXHIBIT_84xxx_           0.0           1
# 26514                                  The Last One           0.0           1
# 26515                                  Trailer Made           0.0           1
# 26516                                    The Church           0.0           1
#
# [26517 rows x 10 columns]

# %%
movie_info_cleaned.head()
# Out:
#     id                                           synopsis rating  \
# 0  1.0  This gritty, fast-paced, and innovative police...      R
# 1  3.0  New York City, not-too-distant-future: Eric Pa...      R
# 2  5.0  Illeana Douglas delivers a superb performance ...      R
# 3  6.0  Michael Douglas runs afoul of a treacherous su...      R
# 5  8.0  The year is 1942. As the Allies unite overseas...     PG
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 5                Drama|Kids and Family       Jay Russell
#
#                             writer theater_date   dvd_date currency  \
# 0                   Ernest Tidyman   1971-10-09 2001-09-25        $
# 1     David Cronenberg|Don DeLillo   2012-08-17 2013-01-01        $
# 2                   Allison Anders   1996-09-13 2000-04-18        $
# 3  Paul Attanasio|Michael Crichton   1994-12-09 1997-08-27        $
# 5                  Gail Gilchriest   2000-03-03 2000-07-11        $
#
#   box_office      runtime                 studio
# 0        NaN  104 minutes                    NaN
# 1    600,000  108 minutes      Entertainment One
# 2        NaN  116 minutes                    NaN
# 3        NaN  128 minutes                    NaN
# 5        NaN   95 minutes  Warner Bros. Pictures

# %%
tmdb_movies.rename(columns={'original_title': 'movie'}, inplace=True)

# %%
movie_info_cleaned.rename(columns={'synopsis': 'movie'}, inplace=True)

# %%
combined_df = pd.merge(movie_info_cleaned, tmdb_movies, on='movie', how='inner')
combined_df.to_csv('combined_table.csv', index=False)

# %%
combined_df = pd.merge(movie_info_cleaned, tmdb_movies, on='movie', how='inner')

combined_df.to_csv('combined_table.csv', index=False)

# %%
combined_df = pd.merge(movie_info_cleaned, tmdb_movies, on='movie', how='outer')
combined_df['movies'] = combined_df['movie'].fillna(combined_df['movie'])
combined_df = combined_df.drop(['movie', 'movie'], axis=1)
combined_df
# Out:
#        id_x rating                                genre          director  \
# 0       1.0      R  Action and Adventure|Classics|Drama  William Friedkin
# 1       3.0      R    Drama|Science Fiction and Fantasy  David Cronenberg
# 2       5.0      R    Drama|Musical and Performing Arts    Allison Anders
# 3       6.0      R           Drama|Mystery and Suspense    Barry Levinson
# 4       8.0     PG                Drama|Kids and Family       Jay Russell
# ...     ...    ...                                  ...               ...
# 27706   NaN    NaN                                  NaN               NaN
# 27707   NaN    NaN                                  NaN               NaN
# 27708   NaN    NaN                                  NaN               NaN
# 27709   NaN    NaN                                  NaN               NaN
# 27710   NaN    NaN                                  NaN               NaN
#
#                                 writer theater_date   dvd_date currency  \
# 0                       Ernest Tidyman   1971-10-09 2001-09-25        $
# 1         David Cronenberg|Don DeLillo   2012-08-17 2013-01-01        $
# 2                       Allison Anders   1996-09-13 2000-04-18        $
# 3      Paul Attanasio|Michael Crichton   1994-12-09 1997-08-27        $
# 4                      Gail Gilchriest   2000-03-03 2000-07-11        $
# ...                                ...          ...        ...      ...
# 27706                              NaN          NaT        NaT      NaN
# 27707                              NaN          NaT        NaT      NaN
# 27708                              NaN          NaT        NaT      NaN
# 27709                              NaN          NaT        NaT      NaN
# 27710                              NaN          NaT        NaT      NaN
#
#       box_office      runtime  ... Unnamed: 0        genre_ids      id_y  \
# 0            NaN  104 minutes  ...        NaN              NaN       NaN
# 1        600,000  108 minutes  ...        NaN              NaN       NaN
# 2            NaN  116 minutes  ...        NaN              NaN       NaN
# 3            NaN  128 minutes  ...        NaN              NaN       NaN
# 4            NaN   95 minutes  ...        NaN              NaN       NaN
# ...          ...          ...  ...        ...              ...       ...
# 27706        NaN          NaN  ...    26512.0         [27, 18]  488143.0
# 27707        NaN          NaN  ...    26513.0         [18, 53]  485975.0
# 27708        NaN          NaN  ...    26514.0     [14, 28, 12]  381231.0
# 27709        NaN          NaN  ...    26515.0  [10751, 12, 28]  366854.0
# 27710        NaN          NaN  ...    26516.0         [53, 27]  309885.0
#
#        original_language popularity  release_date                  title  \
# 0                    NaN        NaN           NaN                    NaN
# 1                    NaN        NaN           NaN                    NaN
# 2                    NaN        NaN           NaN                    NaN
# 3                    NaN        NaN           NaN                    NaN
# 4                    NaN        NaN           NaN                    NaN
# ...                  ...        ...           ...                    ...
# 27706                 en        0.6    2018-10-13  Laboratory Conditions
# 27707                 en        0.6    2018-05-01        _EXHIBIT_84xxx_
# 27708                 en        0.6    2018-10-01           The Last One
# 27709                 en        0.6    2018-06-22           Trailer Made
# 27710                 en        0.6    2018-10-05             The Church
#
#       vote_average  vote_count  \
# 0              NaN         NaN
# 1              NaN         NaN
# 2              NaN         NaN
# 3              NaN         NaN
# 4              NaN         NaN
# ...            ...         ...
# 27706          0.0         1.0
# 27707          0.0         1.0
# 27708          0.0         1.0
# 27709          0.0         1.0
# 27710          0.0         1.0
#
#                                                   movies
# 0      This gritty, fast-paced, and innovative police...
# 1      New York City, not-too-distant-future: Eric Pa...
# 2      Illeana Douglas delivers a superb performance ...
# 3      Michael Douglas runs afoul of a treacherous su...
# 4      The year is 1942. As the Allies unite overseas...
# ...                                                  ...
# 27706                              Laboratory Conditions
# 27707                                    _EXHIBIT_84xxx_
# 27708                                       The Last One
# 27709                                       Trailer Made
# 27710                                         The Church
#
# [27711 rows x 21 columns]

# %%
combined_df.shape
# Out:
# (27711, 21)

# %%
shared_movies = set(movie_info_cleaned['movie']).intersection(set(tmdb_movies['movie']))

# Convert the shared values to a list if needed
shared_movies_list = list(shared_movies)

# Print the shared movie titles
for movie_title in shared_movies_list:
    print(movie_title)

# %%
movie_info_cleaned['theater_date'] = pd.to_datetime(movie_info_cleaned['theater_date'])
tmdb_movies['release_date'] = pd.to_datetime(tmdb_movies['release_date'])

# Merge the DataFrames based on the converted 'theater_dates' and 'release_date' columns
combo = pd.merge(movie_info_cleaned, tmdb_movies, left_on='theater_date', right_on='release_date', how='inner')

# Drop the duplicate 'release_date' column if needed
combo = combo.drop('release_date', axis=1)

# Print the resulting 'combo' DataFrame
combo.head(9)
# Out:
#    id_x                                            movie_x rating  \
# 0   3.0  New York City, not-too-distant-future: Eric Pa...      R
# 1   3.0  New York City, not-too-distant-future: Eric Pa...      R
# 2   3.0  New York City, not-too-distant-future: Eric Pa...      R
# 3   3.0  New York City, not-too-distant-future: Eric Pa...      R
# 4   3.0  New York City, not-too-distant-future: Eric Pa...      R
# 5   3.0  New York City, not-too-distant-future: Eric Pa...      R
# 6   3.0  New York City, not-too-distant-future: Eric Pa...      R
# 7   3.0  New York City, not-too-distant-future: Eric Pa...      R
# 8   3.0  New York City, not-too-distant-future: Eric Pa...      R
#
#                                genre          director  \
# 0  Drama|Science Fiction and Fantasy  David Cronenberg
# 1  Drama|Science Fiction and Fantasy  David Cronenberg
# 2  Drama|Science Fiction and Fantasy  David Cronenberg
# 3  Drama|Science Fiction and Fantasy  David Cronenberg
# 4  Drama|Science Fiction and Fantasy  David Cronenberg
# 5  Drama|Science Fiction and Fantasy  David Cronenberg
# 6  Drama|Science Fiction and Fantasy  David Cronenberg
# 7  Drama|Science Fiction and Fantasy  David Cronenberg
# 8  Drama|Science Fiction and Fantasy  David Cronenberg
#
#                          writer theater_date   dvd_date currency box_office  \
# 0  David Cronenberg|Don DeLillo   2012-08-17 2013-01-01        $    600,000
# 1  David Cronenberg|Don DeLillo   2012-08-17 2013-01-01        $    600,000
# 2  David Cronenberg|Don DeLillo   2012-08-17 2013-01-01        $    600,000
# 3  David Cronenberg|Don DeLillo   2012-08-17 2013-01-01        $    600,000
# 4  David Cronenberg|Don DeLillo   2012-08-17 2013-01-01        $    600,000
# 5  David Cronenberg|Don DeLillo   2012-08-17 2013-01-01        $    600,000
# 6  David Cronenberg|Don DeLillo   2012-08-17 2013-01-01        $    600,000
# 7  David Cronenberg|Don DeLillo   2012-08-17 2013-01-01        $    600,000
# 8  David Cronenberg|Don DeLillo   2012-08-17 2013-01-01        $    600,000
#
#    ...             studio Unnamed: 0            genre_ids    id_y  \
# 0  ...  Entertainment One       5204         [28, 12, 53]   76163
# 1  ...  Entertainment One       5244  [10751, 16, 12, 35]   77174
# 2  ...  Entertainment One       5411                 [18]   49014
# 3  ...  Entertainment One       5644                 [18]  133558
# 4  ...  Entertainment One       5652             [35, 18]  118677
# 5  ...  Entertainment One       5655             [18, 14]  124471
# 6  ...  Entertainment One       5699          [18, 10402]   88036
# 7  ...  Entertainment One       5993                 [99]  125034
# 8  ...  Entertainment One       6147                 [18]  127874
#
#    original_language                              movie_y popularity  \
# 0                 en                    The Expendables 2     17.216
# 1                 en                           ParaNorman     13.320
# 2                 en                           Cosmopolis      7.702
# 3                 en  Saints and Soldiers: Airborne Creed      5.156
# 4                 en                        Why Stop Now?      5.056
# 5                 zh                                  画皮2      4.953
# 6                 en                              Sparkle      4.417
# 7                 en            Out Of The Clear Blue Sky      2.290
# 8                 fr                               Camion      1.851
#
#                                  title vote_average  vote_count
# 0                    The Expendables 2          6.2        4219
# 1                           ParaNorman          6.8        1358
# 2                           Cosmopolis          5.4         546
# 3  Saints and Soldiers: Airborne Creed          5.6          37
# 4                        Why Stop Now?          5.5          54
# 5       Painted Skin: The Resurrection          5.7          33
# 6                              Sparkle          5.9          53
# 7            Out Of The Clear Blue Sky          7.1           6
# 8                               Camion          5.7           5
#
# [9 rows x 21 columns]

# %%
combo = combo.drop_duplicates(subset='id_y', keep='first')

# %%
combo = combo.drop_duplicates(subset='id_x', keep='first')

# %%
combo.shape
# Out:
# (204, 21)

# %%
combo.head(239)
# Out:
#         id_x                                            movie_x rating  \
# 0        3.0  New York City, not-too-distant-future: Eric Pa...      R
# 22      14.0  "Love Ranch" is a bittersweet love story that ...      R
# 27      22.0  Two-time Academy Award Winner Kevin Spacey giv...      R
# 41      23.0  A fictional film set in the alluring world of ...      R
# 64      25.0  From ancient Japan's most enduring tale, the e...  PG-13
# ...      ...                                                ...    ...
# 3433  1968.0  This holiday season, acclaimed filmmaker Camer...     PG
# 3438  1975.0  The year is 1953. A visiting archaeologist cal...     NR
# 3444  1976.0  Embrace of the Serpent features the encounter,...     NR
# 3449  1981.0  Money, Fame and the Knowledge of English. In I...     NR
# 3471  1983.0  This animated children's film spoofs the Sherl...      G
#
#                                                   genre  \
# 0                     Drama|Science Fiction and Fantasy
# 22                                                Drama
# 27                    Comedy|Drama|Mystery and Suspense
# 41                                                Drama
# 64    Action and Adventure|Drama|Science Fiction and...
# ...                                                 ...
# 3433                                       Comedy|Drama
# 3438                                      Drama|Romance
# 3444   Action and Adventure|Art House and International
# 3449                                       Comedy|Drama
# 3471     Action and Adventure|Animation|Kids and Family
#
#                                                director  \
# 0                                      David Cronenberg
# 22                                      Taylor Hackford
# 27                                  George Hickenlooper
# 41                                                  NaN
# 64                                     Carl Erik Rinsch
# ...                                                 ...
# 3433                                      Cameron Crowe
# 3438                               Vikramaditya Motwane
# 3444                                        Ciro Guerra
# 3449                                       Gauri Shinde
# 3471  Burny Mattinson|Ron Clements|John Musker|Dave ...
#
#                                                 writer theater_date  \
# 0                         David Cronenberg|Don DeLillo   2012-08-17
# 22                                       Mark Jacobson   2010-06-30
# 27                                       Norman Snider   2010-12-17
# 41                                                 NaN   2013-12-20
# 64                          Chris Morgan|Hossein Amini   2013-12-25
# ...                                                ...          ...
# 3433                 Aline Brosh McKenna|Cameron Crowe   2011-12-23
# 3438  Vikramaditya Motwane|Bhavani Iyer|Anurag Kashyap   2013-07-03
# 3444              Ciro Guerra|Jacques Toulemonde Vidal   2016-02-17
# 3449                                      Gauri Shinde   2012-10-05
# 3471                                               NaN   1986-07-02
#
#        dvd_date currency  box_office  ...              studio Unnamed: 0  \
# 0    2013-01-01        $     600,000  ...   Entertainment One       5204
# 22   2010-11-09        $     134,904  ...                 NaN        372
# 27   2011-04-05        $   1,039,869  ...        ATO Pictures        116
# 41   2014-03-18        $  99,165,609  ...       Sony Pictures       7992
# 64   2014-04-01        $  20,518,224  ...  Universal Pictures       7883
# ...         ...      ...         ...  ...                 ...        ...
# 3433 2012-04-03        $  72,700,000  ...    20th Century Fox       2638
# 3438 2015-01-12        $     581,813  ...                 NaN       6226
# 3444 2016-06-21        $   1,320,005  ...       Buffalo Films      14550
# 3449 2012-11-20        $   1,416,189  ...  Eros Entertainment       5230
# 3471 2002-07-23        $         NaN  ...                 NaN         56
#
#             genre_ids    id_y  original_language  \
# 0        [28, 12, 53]   76163                 en
# 22               [18]   39845                 en
# 27               [18]   45317                 en
# 41        [12, 10749]  222230                 fr
# 64       [80, 18, 35]  106646                 en
# ...               ...     ...                ...
# 3433  [18, 35, 10751]   74465                 en
# 3438             [99]  193346                 en
# 3444         [12, 18]  336808                 es
# 3449  [16, 35, 10751]   62214                 en
# 3471  [35, 16, 10751]    9994                 en
#
#                             movie_y popularity                          title  \
# 0                 The Expendables 2     17.216              The Expendables 2
# 22                       Love Ranch      6.185                     Love Ranch
# 27                      The Fighter     10.395                    The Fighter
# 41                        Angélique     11.115                      Angelique
# 64          The Wolf of Wall Street     29.518        The Wolf of Wall Street
# ...                             ...        ...                            ...
# 3433                We Bought a Zoo      9.931                We Bought a Zoo
# 3438  Big Star: Nothing Can Hurt Me      1.639  Big Star: Nothing Can Hurt Me
# 3444      El abrazo de la serpiente      6.887         Embrace of the Serpent
# 3449                  Frankenweenie     14.627                  Frankenweenie
# 3471      The Great Mouse Detective     13.348      The Great Mouse Detective
#
#      vote_average  vote_count
# 0             6.2        4219
# 22            6.1          28
# 27            7.3        2325
# 41            6.5          64
# 64            7.9       12411
# ...           ...         ...
# 3433          6.7        1523
# 3438          6.9          14
# 3444          7.8         212
# 3449          6.8        1685
# 3471          7.1         769
#
# [204 rows x 21 columns]

# %%
budgets
# Out:
#       id release_date                                        movie  \
# 0      1   2009-12-18                                       Avatar
# 1      2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2      3   2019-06-07                                 Dark Phoenix
# 3      4   2015-05-01                      Avengers: Age of Ultron
# 4      5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
# ...   ..          ...                                          ...
# 5777  78   2018-12-31                                       Red 11
# 5778  79   1999-04-02                                    Following
# 5779  80   2005-07-13                Return to the Land of Wonders
# 5780  81   2015-09-29                         A Plague So Pleasant
# 5781  82   2005-08-05                            My Date With Drew
#
#       production_budget  domestic_gross  worldwide_gross
# 0           425000000.0     760507625.0     2.776345e+09
# 1           410600000.0     241063875.0     1.045664e+09
# 2           350000000.0      42762350.0     1.497624e+08
# 3           330600000.0     459005868.0     1.403014e+09
# 4           317000000.0     620181382.0     1.316722e+09
# ...                 ...             ...              ...
# 5777             7000.0             0.0     0.000000e+00
# 5778             6000.0         48482.0     2.404950e+05
# 5779             5000.0          1338.0     1.338000e+03
# 5780             1400.0             0.0     0.000000e+00
# 5781             1100.0        181041.0     1.810410e+05
#
# [5782 rows x 6 columns]

# %%
combo.rename(columns={'movie_x': 'synopsis'}, inplace=True)

# %%
combo.rename(columns={'movie_y': 'movie'}, inplace=True)

# %%
combo
# Out:
#         id_x                                           synopsis rating  \
# 0        3.0  New York City, not-too-distant-future: Eric Pa...      R
# 22      14.0  "Love Ranch" is a bittersweet love story that ...      R
# 27      22.0  Two-time Academy Award Winner Kevin Spacey giv...      R
# 41      23.0  A fictional film set in the alluring world of ...      R
# 64      25.0  From ancient Japan's most enduring tale, the e...  PG-13
# ...      ...                                                ...    ...
# 3433  1968.0  This holiday season, acclaimed filmmaker Camer...     PG
# 3438  1975.0  The year is 1953. A visiting archaeologist cal...     NR
# 3444  1976.0  Embrace of the Serpent features the encounter,...     NR
# 3449  1981.0  Money, Fame and the Knowledge of English. In I...     NR
# 3471  1983.0  This animated children's film spoofs the Sherl...      G
#
#                                                   genre  \
# 0                     Drama|Science Fiction and Fantasy
# 22                                                Drama
# 27                    Comedy|Drama|Mystery and Suspense
# 41                                                Drama
# 64    Action and Adventure|Drama|Science Fiction and...
# ...                                                 ...
# 3433                                       Comedy|Drama
# 3438                                      Drama|Romance
# 3444   Action and Adventure|Art House and International
# 3449                                       Comedy|Drama
# 3471     Action and Adventure|Animation|Kids and Family
#
#                                                director  \
# 0                                      David Cronenberg
# 22                                      Taylor Hackford
# 27                                  George Hickenlooper
# 41                                                  NaN
# 64                                     Carl Erik Rinsch
# ...                                                 ...
# 3433                                      Cameron Crowe
# 3438                               Vikramaditya Motwane
# 3444                                        Ciro Guerra
# 3449                                       Gauri Shinde
# 3471  Burny Mattinson|Ron Clements|John Musker|Dave ...
#
#                                                 writer theater_date  \
# 0                         David Cronenberg|Don DeLillo   2012-08-17
# 22                                       Mark Jacobson   2010-06-30
# 27                                       Norman Snider   2010-12-17
# 41                                                 NaN   2013-12-20
# 64                          Chris Morgan|Hossein Amini   2013-12-25
# ...                                                ...          ...
# 3433                 Aline Brosh McKenna|Cameron Crowe   2011-12-23
# 3438  Vikramaditya Motwane|Bhavani Iyer|Anurag Kashyap   2013-07-03
# 3444              Ciro Guerra|Jacques Toulemonde Vidal   2016-02-17
# 3449                                      Gauri Shinde   2012-10-05
# 3471                                               NaN   1986-07-02
#
#        dvd_date currency  box_office  ...              studio Unnamed: 0  \
# 0    2013-01-01        $     600,000  ...   Entertainment One       5204
# 22   2010-11-09        $     134,904  ...                 NaN        372
# 27   2011-04-05        $   1,039,869  ...        ATO Pictures        116
# 41   2014-03-18        $  99,165,609  ...       Sony Pictures       7992
# 64   2014-04-01        $  20,518,224  ...  Universal Pictures       7883
# ...         ...      ...         ...  ...                 ...        ...
# 3433 2012-04-03        $  72,700,000  ...    20th Century Fox       2638
# 3438 2015-01-12        $     581,813  ...                 NaN       6226
# 3444 2016-06-21        $   1,320,005  ...       Buffalo Films      14550
# 3449 2012-11-20        $   1,416,189  ...  Eros Entertainment       5230
# 3471 2002-07-23        $         NaN  ...                 NaN         56
#
#             genre_ids    id_y  original_language  \
# 0        [28, 12, 53]   76163                 en
# 22               [18]   39845                 en
# 27               [18]   45317                 en
# 41        [12, 10749]  222230                 fr
# 64       [80, 18, 35]  106646                 en
# ...               ...     ...                ...
# 3433  [18, 35, 10751]   74465                 en
# 3438             [99]  193346                 en
# 3444         [12, 18]  336808                 es
# 3449  [16, 35, 10751]   62214                 en
# 3471  [35, 16, 10751]    9994                 en
#
#                               movie popularity                          title  \
# 0                 The Expendables 2     17.216              The Expendables 2
# 22                       Love Ranch      6.185                     Love Ranch
# 27                      The Fighter     10.395                    The Fighter
# 41                        Angélique     11.115                      Angelique
# 64          The Wolf of Wall Street     29.518        The Wolf of Wall Street
# ...                             ...        ...                            ...
# 3433                We Bought a Zoo      9.931                We Bought a Zoo
# 3438  Big Star: Nothing Can Hurt Me      1.639  Big Star: Nothing Can Hurt Me
# 3444      El abrazo de la serpiente      6.887         Embrace of the Serpent
# 3449                  Frankenweenie     14.627                  Frankenweenie
# 3471      The Great Mouse Detective     13.348      The Great Mouse Detective
#
#      vote_average  vote_count
# 0             6.2        4219
# 22            6.1          28
# 27            7.3        2325
# 41            6.5          64
# 64            7.9       12411
# ...           ...         ...
# 3433          6.7        1523
# 3438          6.9          14
# 3444          7.8         212
# 3449          6.8        1685
# 3471          7.1         769
#
# [204 rows x 21 columns]

# %%
zaza = pd.merge(combo, budgets, on='movie', how='inner')
zaza
# Out:
#        id_x                                           synopsis rating  \
# 0       3.0  New York City, not-too-distant-future: Eric Pa...      R
# 1      14.0  "Love Ranch" is a bittersweet love story that ...      R
# 2      22.0  Two-time Academy Award Winner Kevin Spacey giv...      R
# 3      25.0  From ancient Japan's most enduring tale, the e...  PG-13
# 4      54.0  Journalist Jep Gambardella (the dazzling Toni ...     NR
# ..      ...                                                ...    ...
# 110  1944.0  In the 3D action-comedy The Green Hornet, Brit...  PG-13
# 111  1945.0  Left on a nun's doorstep, Larry, Curly and Moe...     PG
# 112  1953.0  A glimpse into the comedic process and private...      R
# 113  1968.0  This holiday season, acclaimed filmmaker Camer...     PG
# 114  1981.0  Money, Fame and the Knowledge of English. In I...     NR
#
#                                                  genre  \
# 0                    Drama|Science Fiction and Fantasy
# 1                                                Drama
# 2                    Comedy|Drama|Mystery and Suspense
# 3    Action and Adventure|Drama|Science Fiction and...
# 4                                         Comedy|Drama
# ..                                                 ...
# 110  Action and Adventure|Comedy|Science Fiction an...
# 111                                             Comedy
# 112                      Comedy|Documentary|Television
# 113                                       Comedy|Drama
# 114                                       Comedy|Drama
#
#                           director  \
# 0                 David Cronenberg
# 1                  Taylor Hackford
# 2              George Hickenlooper
# 3                 Carl Erik Rinsch
# 4                 Paolo Sorrentino
# ..                             ...
# 110                  Michel Gondry
# 111  Bobby Farrelly|Peter Farrelly
# 112      Ricki Stern|Anne Sundberg
# 113                  Cameron Crowe
# 114                   Gauri Shinde
#
#                                          writer theater_date   dvd_date  \
# 0                  David Cronenberg|Don DeLillo   2012-08-17 2013-01-01
# 1                                 Mark Jacobson   2010-06-30 2010-11-09
# 2                                 Norman Snider   2010-12-17 2011-04-05
# 3                    Chris Morgan|Hossein Amini   2013-12-25 2014-04-01
# 4           Paolo Sorrentino|Umberto Contarello   2013-11-15 2014-03-25
# ..                                          ...          ...        ...
# 110                    Evan Goldberg|Seth Rogen   2011-01-14 2011-05-03
# 111  Bobby Farrelly|Peter Farrelly|Mike Cerrone   2012-04-13 2012-07-17
# 112                                 Ricki Stern   2010-06-11 2010-12-14
# 113           Aline Brosh McKenna|Cameron Crowe   2011-12-23 2012-04-03
# 114                                Gauri Shinde   2012-10-05 2012-11-20
#
#     currency  box_office  ...                    movie popularity  \
# 0          $     600,000  ...        The Expendables 2     17.216
# 1          $     134,904  ...               Love Ranch      6.185
# 2          $   1,039,869  ...              The Fighter     10.395
# 3          $  20,518,224  ...  The Wolf of Wall Street     29.518
# 4          $         NaN  ...       La grande bellezza      9.937
# ..       ...         ...  ...                      ...        ...
# 110        $  98,000,000  ...         Barney's Version      7.357
# 111        $  41,800,000  ...                  Lockout     11.273
# 112        $   2,927,972  ...               The A-Team     17.097
# 113        $  72,700,000  ...          We Bought a Zoo      9.931
# 114        $   1,416,189  ...            Frankenweenie     14.627
#
#                        title vote_average  vote_count  id release_date  \
# 0          The Expendables 2          6.2        4219  81   2012-08-17
# 1                 Love Ranch          6.1          28  19   2010-06-30
# 2                The Fighter          7.3        2325  68   2010-12-10
# 3    The Wolf of Wall Street          7.9       12411  76   2013-12-25
# 4           The Great Beauty          7.4        1518  23   2013-11-15
# ..                       ...          ...         ...  ..          ...
# 110         Barney's Version          7.2         210  86   2011-01-14
# 111                  Lockout          5.9        1004  22   2012-04-13
# 112               The A-Team          6.3        2703  32   2010-06-11
# 113          We Bought a Zoo          6.7        1523  14   2011-12-23
# 114            Frankenweenie          6.8        1685  48   2012-10-05
#
#      production_budget domestic_gross  worldwide_gross
# 0          100000000.0     85028192.0      311979256.0
# 1           25000000.0       137885.0         146149.0
# 2           11000000.0     93617009.0      129262388.0
# 3          100000000.0    116900694.0      389870414.0
# 4           12000000.0      2883879.0       29549145.0
# ..                 ...            ...              ...
# 110         30000000.0      7502560.0        8845575.0
# 111         20000000.0     14326865.0       33943049.0
# 112        110000000.0     77222099.0      177241171.0
# 113         50000000.0     75624550.0      118729073.0
# 114         39000000.0     35287788.0       81150788.0
#
# [115 rows x 26 columns]

# %%
zaza.shape
# Out:
# (115, 26)

# %%
zaza = pd.merge(combo, budgets, on='movie', how='inner')
zaza_subset = zaza.head(115)
zaza_subset
# Out:
#        id_x                                           synopsis rating  \
# 0       3.0  New York City, not-too-distant-future: Eric Pa...      R
# 1      14.0  "Love Ranch" is a bittersweet love story that ...      R
# 2      22.0  Two-time Academy Award Winner Kevin Spacey giv...      R
# 3      25.0  From ancient Japan's most enduring tale, the e...  PG-13
# 4      54.0  Journalist Jep Gambardella (the dazzling Toni ...     NR
# ..      ...                                                ...    ...
# 110  1944.0  In the 3D action-comedy The Green Hornet, Brit...  PG-13
# 111  1945.0  Left on a nun's doorstep, Larry, Curly and Moe...     PG
# 112  1953.0  A glimpse into the comedic process and private...      R
# 113  1968.0  This holiday season, acclaimed filmmaker Camer...     PG
# 114  1981.0  Money, Fame and the Knowledge of English. In I...     NR
#
#                                                  genre  \
# 0                    Drama|Science Fiction and Fantasy
# 1                                                Drama
# 2                    Comedy|Drama|Mystery and Suspense
# 3    Action and Adventure|Drama|Science Fiction and...
# 4                                         Comedy|Drama
# ..                                                 ...
# 110  Action and Adventure|Comedy|Science Fiction an...
# 111                                             Comedy
# 112                      Comedy|Documentary|Television
# 113                                       Comedy|Drama
# 114                                       Comedy|Drama
#
#                           director  \
# 0                 David Cronenberg
# 1                  Taylor Hackford
# 2              George Hickenlooper
# 3                 Carl Erik Rinsch
# 4                 Paolo Sorrentino
# ..                             ...
# 110                  Michel Gondry
# 111  Bobby Farrelly|Peter Farrelly
# 112      Ricki Stern|Anne Sundberg
# 113                  Cameron Crowe
# 114                   Gauri Shinde
#
#                                          writer theater_date   dvd_date  \
# 0                  David Cronenberg|Don DeLillo   2012-08-17 2013-01-01
# 1                                 Mark Jacobson   2010-06-30 2010-11-09
# 2                                 Norman Snider   2010-12-17 2011-04-05
# 3                    Chris Morgan|Hossein Amini   2013-12-25 2014-04-01
# 4           Paolo Sorrentino|Umberto Contarello   2013-11-15 2014-03-25
# ..                                          ...          ...        ...
# 110                    Evan Goldberg|Seth Rogen   2011-01-14 2011-05-03
# 111  Bobby Farrelly|Peter Farrelly|Mike Cerrone   2012-04-13 2012-07-17
# 112                                 Ricki Stern   2010-06-11 2010-12-14
# 113           Aline Brosh McKenna|Cameron Crowe   2011-12-23 2012-04-03
# 114                                Gauri Shinde   2012-10-05 2012-11-20
#
#     currency  box_office  ...                    movie popularity  \
# 0          $     600,000  ...        The Expendables 2     17.216
# 1          $     134,904  ...               Love Ranch      6.185
# 2          $   1,039,869  ...              The Fighter     10.395
# 3          $  20,518,224  ...  The Wolf of Wall Street     29.518
# 4          $         NaN  ...       La grande bellezza      9.937
# ..       ...         ...  ...                      ...        ...
# 110        $  98,000,000  ...         Barney's Version      7.357
# 111        $  41,800,000  ...                  Lockout     11.273
# 112        $   2,927,972  ...               The A-Team     17.097
# 113        $  72,700,000  ...          We Bought a Zoo      9.931
# 114        $   1,416,189  ...            Frankenweenie     14.627
#
#                        title vote_average  vote_count  id release_date  \
# 0          The Expendables 2          6.2        4219  81   2012-08-17
# 1                 Love Ranch          6.1          28  19   2010-06-30
# 2                The Fighter          7.3        2325  68   2010-12-10
# 3    The Wolf of Wall Street          7.9       12411  76   2013-12-25
# 4           The Great Beauty          7.4        1518  23   2013-11-15
# ..                       ...          ...         ...  ..          ...
# 110         Barney's Version          7.2         210  86   2011-01-14
# 111                  Lockout          5.9        1004  22   2012-04-13
# 112               The A-Team          6.3        2703  32   2010-06-11
# 113          We Bought a Zoo          6.7        1523  14   2011-12-23
# 114            Frankenweenie          6.8        1685  48   2012-10-05
#
#      production_budget domestic_gross  worldwide_gross
# 0          100000000.0     85028192.0      311979256.0
# 1           25000000.0       137885.0         146149.0
# 2           11000000.0     93617009.0      129262388.0
# 3          100000000.0    116900694.0      389870414.0
# 4           12000000.0      2883879.0       29549145.0
# ..                 ...            ...              ...
# 110         30000000.0      7502560.0        8845575.0
# 111         20000000.0     14326865.0       33943049.0
# 112        110000000.0     77222099.0      177241171.0
# 113         50000000.0     75624550.0      118729073.0
# 114         39000000.0     35287788.0       81150788.0
#
# [115 rows x 26 columns]

# %%
zaza.shape
# Out:
# (115, 26)

# %%
zaza_subset.shape
# Out:
# (115, 26)

# %%
zaza_subset.isnull().sum()
# Out:
# id_x                  0
# synopsis              0
# rating                0
# genre                 0
# director             11
# writer               14
# theater_date          0
# dvd_date              0
# currency              0
# box_office           36
# runtime               0
# studio               25
# Unnamed: 0            0
# genre_ids             0
# id_y                  0
# original_language     0
# movie                 0
# popularity            0
# title                 0
# vote_average          0
# vote_count            0
# id                    0
# release_date          0
# production_budget     0
# domestic_gross        0
# worldwide_gross       0
# dtype: int64

# %%
zaza_subset.loc[1, 'studio'] = 'Entertainment One'
zaza_subset.loc[5, 'studio'] = 'Silver Pictures'
zaza_subset.loc[7, 'studio'] = 'New Line Cinema'
zaza_subset.loc[13, 'studio'] = 'Samuel Goldwyn Productions'
zaza_subset.loc[19, 'studio'] = 'DreamWorks Pictures'
zaza_subset.loc[21, 'studio'] = 'A-Team Productions'
zaza_subset.loc[22, 'studio'] = 'Walt Disney Pictures'
zaza_subset.loc[27, 'studio'] = 'Stanley Kubrick Productions'
zaza_subset.loc[28, 'studio'] = 'Pacific Western Productions'
zaza_subset.loc[33, 'studio'] = 'Laika'
zaza_subset.loc[35, 'studio'] = 'Dimension Films'
zaza_subset.loc[40, 'studio'] = '20th Century Fox'
zaza_subset.loc[42, 'studio'] = 'Walt Disney Pictures|Pixar Animation Studios'
zaza_subset.loc[49, 'studio'] = 'Killer Films'
zaza_subset.loc[53, 'studio'] = 'Anton Capital'
zaza_subset.loc[55, 'studio'] = 'The Ladd Company'
zaza_subset.loc[76, 'studio'] = 'Columbia Pictures'
zaza_subset.loc[77, 'studio'] = 'Relativity Media'
zaza_subset.loc[79, 'studio'] = 'Summit Entertainment'
zaza_subset.loc[80, 'studio'] = 'Sunlight Productions'
zaza_subset.loc[84, 'studio'] = 'Atlas Entertainment'
zaza_subset.loc[93, 'studio'] = 'Bona Film Group'
zaza_subset.loc[102, 'studio'] = 'DreamWorks Pictures'
zaza_subset.loc[106, 'studio'] = 'Columbia Pictures'
zaza_subset.loc[108, 'studio'] = 'EuropaCorp'

# %%
fufu = zaza_subset.sort_values(by='box_office')
fufu.tail(36)
# Out:
#        id_x                                           synopsis rating  \
# 4      54.0  Journalist Jep Gambardella (the dazzling Toni ...     NR
# 5      56.0  Albert Hughes and his brother Allen Hughes fol...      R
# 7      64.0  Somewhere in the naked city lurks a one-armed,...  PG-13
# 13    110.0  This is director Frank Capra's classic bitters...     PG
# 14    115.0  "Toy Story 2" is the exciting, all-new sequel ...      G
# 21    276.0  Carl Reiner directs Steve Martin (who co-wrote...      R
# 22    283.0  This pure-pulp thrill ride jumps between past ...     NR
# 25    353.0  Robert (character actor David Thornton) is a g...     NR
# 26    353.0  Robert (character actor David Thornton) is a g...     NR
# 27    387.0  In this western, Will Penny is an aging and im...     NR
# 28    400.0  Disaster follows when a long-dormant volcano s...  PG-13
# 29    419.0  When teens mysteriously develop powerful new a...  PG-13
# 35    508.0  In this action-horror flick from director Robe...      R
# 36    518.0  Since the moment they met at age 5, Rosie (Lil...      R
# 40    608.0  Some people have bad days. Henry Altmann (Will...      R
# 42    612.0  Actors Woody Harrelson and Wesley Snipes team ...      R
# 43    633.0  One of Filmmaker Magazine's "25 New Faces of I...     NR
# 49    769.0  Reverend Ernst Toller (Ethan Hawke) is a solit...      R
# 52    836.0  At the end of the nineteenth century, 16-year-...      R
# 53    875.0  Set in the world of electronic music and Holly...      R
# 55    984.0  A teenager and his kid brother spar with their...  PG-13
# 58   1036.0  With THE FITZGERALD FAMILY CHRISTMAS, Burns re...  PG-13
# 60   1076.0  Bosnia. Rwanda. Kosovo. Sierra Leone. Pakistan...     NR
# 66   1138.0  When once-up-and-coming indie film starlet Hal...  PG-13
# 67   1138.0  When once-up-and-coming indie film starlet Hal...  PG-13
# 70   1220.0  Filmed in the California desert on Super 16mm,...     NR
# 76   1297.0  Based on true events, WOMAN WALKS AHEAD tells ...      R
# 77   1318.0  This animated adventure for kids stars Barbie ...     NR
# 82   1487.0  In the highly anticipated sequel, which was in...  PG-13
# 95   1691.0  I ORIGINS, the second feature film from writer...      R
# 97   1704.0  During the winter of 1952, British authorities...  PG-13
# 101  1762.0  Adapted from the bestselling novel by author J...  PG-13
# 103  1819.0  In the year 2045, people can escape their hars...  PG-13
# 106  1845.0  A group of wealthy boys in Los Angeles during ...      R
# 107  1886.0  "Houston, we have a problem." Those words were...     PG
# 109  1937.0  Starring Shailene Woodley (Fault in Our Stars,...  PG-13
#
#                                                  genre  \
# 4                                         Comedy|Drama
# 5                                                Drama
# 7                                               Comedy
# 13   Classics|Comedy|Drama|Kids and Family|Science ...
# 14   Animation|Comedy|Kids and Family|Science Ficti...
# 21                                              Comedy
# 22                                Mystery and Suspense
# 25            Art House and International|Comedy|Drama
# 26            Art House and International|Comedy|Drama
# 27       Action and Adventure|Classics|Western|Romance
# 28                                Action and Adventure
# 29    Mystery and Suspense|Science Fiction and Fantasy
# 35                   Drama|Horror|Mystery and Suspense
# 36                                      Comedy|Romance
# 40                                        Comedy|Drama
# 42   Action and Adventure|Comedy|Drama|Mystery and ...
# 43                                               Drama
# 49                                               Drama
# 52           Action and Adventure|Mystery and Suspense
# 53                                               Drama
# 55                          Drama|Mystery and Suspense
# 58                                               Drama
# 60                        Documentary|Special Interest
# 66                                              Comedy
# 67                                              Comedy
# 70                          Drama|Mystery and Suspense
# 76                                               Drama
# 77                           Animation|Kids and Family
# 82                                      Comedy|Romance
# 95                   Drama|Science Fiction and Fantasy
# 97                          Drama|Mystery and Suspense
# 101                                              Drama
# 103   Action and Adventure|Science Fiction and Fantasy
# 106                         Drama|Mystery and Suspense
# 107                         Action and Adventure|Drama
# 109                                      Drama|Romance
#
#                        director  \
# 4              Paolo Sorrentino
# 5    Allen Hughes|Albert Hughes
# 7                     Pat Proft
# 13                  Frank Capra
# 14                John Lasseter
# 21                  Carl Reiner
# 22               Mickey Keating
# 25               Darko Lungulov
# 26               Darko Lungulov
# 27                    Tom Gries
# 28              Roger Donaldson
# 29          Jennifer Yuh Nelson
# 35             Robert Rodriguez
# 36             Christian Ditter
# 40          Phil Alden Robinson
# 42                 Joseph Ruben
# 43                     Tze Chun
# 49                Paul Schrader
# 52                          NaN
# 53                   Max Joseph
# 55                Michael Apted
# 58                 Edward Burns
# 60                 Mark Hopkins
# 66                 Michael Urie
# 67                 Michael Urie
# 70                    Oren Shai
# 76                Susanna White
# 77                          NaN
# 82                    Tim Story
# 95                  Mike Cahill
# 97                Morten Tyldum
# 101               Jake Schreier
# 103            Steven Spielberg
# 106                   James Cox
# 107                  Ron Howard
# 109                         NaN
#
#                                                 writer theater_date  \
# 4                  Paolo Sorrentino|Umberto Contarello   2013-11-15
# 5       Michael Henry Brown|Albert Hughes|Allen Hughes   1995-10-06
# 7                                            Pat Proft   1998-08-21
# 13         Frank Capra|Frances Goodrich|Albert Hackett   1946-12-25
# 14   Doug Chamberlain|Rita Hsiao|Doug Chamberlin|Ch...   1999-11-24
# 21            Steve Martin|Carl Gottlieb|Michael Elias   1979-12-14
# 22                                      Mickey Keating   2016-07-01
# 25                                      Darko Lungulov   2010-05-14
# 26                                      Darko Lungulov   2010-05-14
# 27                                           Tom Gries   1968-04-10
# 28                                        Leslie Bohem   1997-02-07
# 29                                          Chad Hodge   2018-08-03
# 35                   Robert Krutzman|Quentin Tarantino   1996-01-19
# 36                                    Juliette Towhidi   2015-02-06
# 40                                      Daniel Taplitz   2014-05-23
# 42                      David Loughery|Doug Richardson   1995-11-22
# 43                                            Tze Chun   2010-03-12
# 49                                       Paul Schrader   2018-05-18
# 52                                                 NaN   2015-05-15
# 53                      Max Joseph|Meaghan Oppenheimer   2015-08-28
# 55                                          Ron Koslow   1984-06-01
# 58                                        Edward Burns   2012-12-07
# 60                                                 NaN   2010-06-04
# 66                           Halley Feiffer|Ryan Spahn   2013-05-10
# 67                           Halley Feiffer|Ryan Spahn   2013-05-10
# 70                             Oren Shai|Webb Wilcoxen   2016-10-28
# 76                                       Steven Knight   2018-06-29
# 77                                         Elise Allen   2010-05-01
# 82                                                 NaN   2014-06-20
# 95                                         Mike Cahill   2014-07-18
# 97                                        Graham Moore   2014-11-28
# 101                                                NaN   2015-07-24
# 103                              Zak Penn|Ernest Cline   2018-03-29
# 106                          Captain Mauzner|James Cox   2018-08-17
# 107                         Al Reinert|William Broyles   1995-06-30
# 109  Aaron Kandell|Jordan Kandell|David Branson Smi...   2018-06-01
#
#       dvd_date currency box_office  ...                        movie  \
# 4   2014-03-25        $        NaN  ...           La grande bellezza
# 5   1998-05-19        $        NaN  ...                    Assassins
# 7   1998-12-22        $        NaN  ...                        Blade
# 13  1995-09-19        $        NaN  ...  The Best Years of Our Lives
# 14  2000-10-17        $        NaN  ...                  Toy Story 2
# 21  2005-07-26        $        NaN  ...                         1941
# 22  2016-07-01        $        NaN  ...                      The BFG
# 25  2010-07-13        $        NaN  ...                   Robin Hood
# 26  2010-07-13        $        NaN  ...                   Robin Hood
# 27  2002-06-04        $        NaN  ...        2001: A Space Odyssey
# 28  1998-01-20        $        NaN  ...                 Dante's Peak
# 29  2018-10-30        $        NaN  ...            The Darkest Minds
# 35  1998-06-15        $        NaN  ...          From Dusk Till Dawn
# 36  2015-05-05        $        NaN  ...                  Seventh Son
# 40  2014-07-22        $        NaN  ...   X-Men: Days of Future Past
# 42  2001-05-22        $        NaN  ...                    Toy Story
# 43  2010-08-10        $        NaN  ...                  Remember Me
# 49  2018-08-21        $        NaN  ...               First Reformed
# 52  2015-07-07        $        NaN  ...           Mad Max: Fury Road
# 53  2015-11-17        $        NaN  ...          We Are Your Friends
# 55  2012-07-31        $        NaN  ...  Once Upon a Time in America
# 58  2013-11-05        $        NaN  ...                     Deadfall
# 60  2010-12-01        $        NaN  ...                      Killers
# 66  2013-09-23        $        NaN  ...             The Great Gatsby
# 67  2013-09-23        $        NaN  ...             The Great Gatsby
# 70  2016-12-06        $        NaN  ...                      Inferno
# 76  2018-08-28        $        NaN  ...  Sicario: Day of the Soldado
# 77  2010-03-09        $        NaN  ...            Charlie St. Cloud
# 82  2014-09-16        $        NaN  ...         Think Like a Man Too
# 95  2014-12-09        $        NaN  ...           The Purge: Anarchy
# 97  2015-03-31        $        NaN  ...                 The Babadook
# 101 2015-10-20        $        NaN  ...                     Southpaw
# 103 2018-07-03        $        NaN  ...             Ready Player One
# 106 2018-09-18        $        NaN  ...                        Alpha
# 107 2004-09-07        $        NaN  ...                    Apollo 13
# 109 2018-08-21        $        NaN  ...                      Upgrade
#
#     popularity                        title vote_average  vote_count   id  \
# 4        9.937             The Great Beauty          7.4        1518   23
# 5       10.579                    Assassins          6.2         666   63
# 7       17.175                        Blade          6.6        3137   71
# 13       9.647  The Best Years of Our Lives          7.8         243   78
# 14      22.698                  Toy Story 2          7.5        7553   40
# 21       9.755                         1941          5.7         262    4
# 22      20.080                      The BFG          6.2        1916   17
# 25      15.444                   Robin Hood          6.3        2569   39
# 26      15.444                   Robin Hood          6.3        2569    9
# 27      23.781        2001: A Space Odyssey          8.0        5837   27
# 28      13.514                 Dante's Peak          5.9         783    9
# 29      23.967            The Darkest Minds          6.8        1158   64
# 35      16.064          From Dusk Till Dawn          7.0        3015   77
# 36      22.856                  Seventh Son          5.3        1549   24
# 40      41.867   X-Men: Days of Future Past          7.5       10062   55
# 42      28.005                    Toy Story          7.9       10174   37
# 43      11.453                  Remember Me          7.1        2079   51
# 49      12.943               First Reformed          6.9         446   11
# 52      28.099           Mad Max: Fury Road          7.4       14454   75
# 53      10.809          We Are Your Friends          6.3        1241   20
# 55      17.717  Once Upon a Time in America          8.4        2243   89
# 58       9.491                     Deadfall          5.9         357   83
# 60      10.221                      Killers          5.8        1314   54
# 66      15.397             The Great Gatsby          7.4        7120   70
# 67      15.397             The Great Gatsby          7.4        7120  100
# 70      17.410                      Inferno          5.9        3877   64
# 76      29.725  Sicario: Day of the Soldado          6.7        1317   59
# 77       9.454            Charlie St. Cloud          6.9        1398   31
# 82       8.250         Think Like a Man Too          6.3         319   36
# 95      28.424           The Purge: Anarchy          6.6        3754   71
# 97      11.502                 The Babadook          6.4        3528   41
# 101     25.305                     Southpaw          7.4        3424   92
# 103     30.029             Ready Player One          7.6        7021   78
# 106     24.536                        Alpha          5.9        1167   79
# 107     15.855                    Apollo 13          7.4        2821   75
# 109     21.413                      Upgrade          7.4        1326   89
#
#     release_date  production_budget domestic_gross  worldwide_gross
# 4     2013-11-15         12000000.0      2883879.0       29549145.0
# 5     1995-10-06         50000000.0     30306268.0       83306268.0
# 7     1998-08-21         45000000.0     70141876.0      131237688.0
# 13    1946-11-21          2100000.0     23600000.0       23600000.0
# 14    1999-11-19         90000000.0    245852179.0      511358276.0
# 21    1979-12-14         32000000.0     34175000.0       94875000.0
# 22    2016-07-01        140000000.0     55483770.0      199646680.0
# 25    2010-05-14        210000000.0    105487148.0      322459006.0
# 26    2018-11-21         99000000.0     30824628.0       84747441.0
# 27    1968-04-02         10500000.0     59936321.0       71928046.0
# 28    1997-02-07        115000000.0     67163857.0      178200000.0
# 29    2018-08-03         34000000.0     12695691.0       38361428.0
# 35    1996-01-19         20000000.0     25728961.0       25732986.0
# 36    2015-02-06         95000000.0     17725785.0      108874967.0
# 40    2014-05-23        200000000.0    233921534.0      747862775.0
# 42    1995-11-22         30000000.0    191796233.0      364545516.0
# 43    2010-03-12         16000000.0     19068240.0       56506120.0
# 49    2018-05-18          3500000.0      3448256.0        3874772.0
# 52    2015-05-15        150000000.0    153636354.0      370098020.0
# 53    2015-08-28          2000000.0      3591417.0       10153415.0
# 55    1984-06-01         30000000.0      5321508.0        5575648.0
# 58    2012-12-07          6000000.0        66351.0        1673635.0
# 60    2010-06-04         75000000.0     47059963.0       95572749.0
# 66    2013-05-10        190000000.0    144840419.0      351040419.0
# 67    1974-03-29          7000000.0     26533200.0       26533200.0
# 70    2016-10-28         75000000.0     34343574.0      219519367.0
# 76    2018-06-29         35000000.0     50065850.0       75885196.0
# 77    2010-07-30         44000000.0     31206263.0       48478084.0
# 82    2014-06-20         24000000.0     65028687.0       70027933.0
# 95    2014-07-18          9000000.0     71562550.0      111534881.0
# 97    2014-11-28          2000000.0       950792.0        7482387.0
# 101   2015-07-24         30000000.0     52421953.0       94156456.0
# 103   2018-03-29        150000000.0    137690172.0      579290136.0
# 106   2018-08-17         51000000.0     35851379.0       99624873.0
# 107   1995-06-30         65000000.0    173772767.0      335802271.0
# 109   2018-06-01          3000000.0     11977130.0       16553285.0
#
# [36 rows x 26 columns]

# %%
zaza_subset.loc[97, 'box_office'] = '10484459'

# %%
zaza_subset.loc[101, 'box_office'] = '91970827'

# %%
zaza_subset.loc[103, 'box_office'] = '607274134'

# %%
zaza_subset.loc[106, 'box_office'] = '99630675'

# %%
zaza_subset.loc[107, 'box_office'] = '355237933'

# %%
zaza_subset.loc[109, 'box_office'] = '16706680'

# %%
zaza_subset.loc[60, 'box_office'] = '98159963'

# %%
zaza_subset.loc[66, 'box_office'] = '353659851'

# %%
zaza_subset.loc[76, 'box_office'] = '75837743'

# %%
zaza_subset.loc[70, 'box_office'] = '220021259'

# %%
zaza_subset.loc[77, 'box_office'] = '48190704'

# %%
zaza_subset = zaza_subset.drop(67)

# %%
zaza_subset.loc[82, 'box_office'] = '70181428'

# %%
zaza_subset.loc[95, 'box_office'] = '111928365'

# %%
zaza_subset.loc[4, 'box_office'] = '24337766'

# %%
zaza_subset.loc[5, 'box_office'] = '30303072'

# %%
zaza_subset.loc[7, 'box_office'] = '131211377'

# %%
zaza_subset.loc[13, 'box_office'] = '23661347'

# %%
zaza_subset.loc[14, 'box_office'] = '497375381'

# %%
zaza_subset.loc[21, 'box_office'] = '92455742'

# %%
zaza_subset.loc[22, 'box_office'] = '195243411'

# %%
zaza_subset.loc[25, 'box_office'] = '321669741'

# %%
zaza_subset = zaza_subset.drop(26)

# %%
zaza_subset.loc[27, 'box_office'] = '66441232'

# %%
zaza_subset.loc[28, 'box_office'] = '178127760'

# %%
zaza_subset.loc[29, 'box_office'] = '41142379'

# %%
zaza_subset.loc[35, 'box_office'] = '25837111'

# %%
zaza_subset.loc[36, 'box_office'] = '114178613'

# %%
zaza_subset.loc[40, 'box_office'] = '746045700'

# %%
zaza_subset.loc[42, 'box_office'] = '394436586'

# %%
zaza_subset.loc[43, 'box_office'] = '56032889'

# %%
zaza_subset.loc[49, 'box_office'] = '3862498'

# %%
zaza_subset.loc[52, 'box_office'] = '380080290'

# %%
zaza_subset.loc[55, 'box_office'] = '5474090'

# %%
zaza_subset.loc[58, 'box_office'] = '1946254'

# %%
zaza_subset.loc[53, 'box_office'] = '11122090'

# %%
fufu = zaza_subset.sort_values(by='studio')
fufu.tail(25)
# Out:
#        id_x                                           synopsis rating  \
# 55    984.0  A teenager and his kid brother spar with their...  PG-13
# 73   1237.0  Sarah Jessica Parker, Greg Kinnear, Pierce Bro...  PG-13
# 75   1268.0  After ten years of marriage, Jeff and Nealy La...      R
# 6      57.0  Life doesn't always go according to plan. Pat ...      R
# 97   1704.0  During the winter of 1952, British authorities...  PG-13
# 20    251.0  In this adaptation of the novel "The Price of ...      R
# 58   1036.0  With THE FITZGERALD FAMILY CHRISTMAS, Burns re...  PG-13
# 61   1084.0  Shy, sensitive April (Emma Roberts) is the cla...      R
# 60   1076.0  Bosnia. Rwanda. Kosovo. Sierra Leone. Pakistan...     NR
# 30    433.0  The best-selling suspense novel by late author...  PG-13
# 3      25.0  From ancient Japan's most enduring tale, the e...  PG-13
# 96   1695.0  The second chapter in the "Bourne Trilogy," ba...  PG-13
# 9      77.0  Until he was downsized, affable, amiable Larry...  PG-13
# 78   1321.0  In his follow-up to the four-time Academy Awar...  PG-13
# 63   1114.0  When four lifelong friends-Regina Hall, Queen ...      R
# 107  1886.0  "Houston, we have a problem." Those words were...     PG
# 22    283.0  This pure-pulp thrill ride jumps between past ...     NR
# 42    612.0  Actors Woody Harrelson and Wesley Snipes team ...      R
# 65   1136.0  The Hobbit: An Unexpected Journey follows titl...  PG-13
# 98   1718.0  Adonis Johnson Creed (Michael B. Jordan), the ...  PG-13
# 56   1011.0  In Final Destination 5, Death is just as omnip...      R
# 103  1819.0  In the year 2045, people can escape their hars...  PG-13
# 24    338.0  "Hereafter" tells the story of three people wh...  PG-13
# 37    554.0  1970s-era DC antihero Jonah Hex makes his way ...  PG-13
# 47    689.0  "Inherent Vice," is the seventh feature from P...      R
#
#                                                  genre              director  \
# 55                          Drama|Mystery and Suspense         Michael Apted
# 73                                              Comedy       Douglas McGrath
# 75                                              Comedy     Jacob Aaron Estes
# 6                                               Comedy                   NaN
# 97                          Drama|Mystery and Suspense         Morten Tyldum
# 20                                       Drama|Romance           Todd Haynes
# 58                                               Drama          Edward Burns
# 61                                               Drama           Gia Coppola
# 60                        Documentary|Special Interest          Mark Hopkins
# 30           Action and Adventure|Mystery and Suspense            Doug Liman
# 3    Action and Adventure|Drama|Science Fiction and...      Carl Erik Rinsch
# 96     Action and Adventure|Drama|Mystery and Suspense       Paul Greengrass
# 9                                         Comedy|Drama             Tom Hanks
# 78                                               Drama           Tate Taylor
# 63                                        Comedy|Drama                   NaN
# 107                         Action and Adventure|Drama            Ron Howard
# 22                                Mystery and Suspense        Mickey Keating
# 42   Action and Adventure|Comedy|Drama|Mystery and ...          Joseph Ruben
# 65    Action and Adventure|Science Fiction and Fantasy         Peter Jackson
# 98                                               Drama          Ryan Coogler
# 56                                              Horror          Steven Quale
# 103   Action and Adventure|Science Fiction and Fantasy      Steven Spielberg
# 24                          Drama|Mystery and Suspense        Clint Eastwood
# 37           Action and Adventure|Drama|Horror|Western         Jimmy Hayward
# 47                          Drama|Mystery and Suspense  Paul Thomas Anderson
#
#                                                 writer theater_date  \
# 55                                          Ron Koslow   1984-06-01
# 73                                 Aline Brosh McKenna   2011-09-16
# 75                                   Jacob Aaron Estes   2012-11-02
# 6                                                  NaN   2012-11-21
# 97                                        Graham Moore   2014-11-28
# 20                                        Phyllis Nagy   2015-11-20
# 58                                        Edward Burns   2012-12-07
# 61                                         Gia Coppola   2014-05-09
# 60                                                 NaN   2010-06-04
# 30                    Tony Gilroy|William Blake Herron   2002-06-14
# 3                           Chris Morgan|Hossein Amini   2013-12-25
# 96                                         Tony Gilroy   2004-07-23
# 9                               Tom Hanks|Nia Vardalos   2011-07-01
# 78   Tate Taylor|Jez Butterworth|John-Henry Butterw...   2014-08-01
# 63                           Kenya Barris|Tracy Oliver   2017-07-21
# 107                         Al Reinert|William Broyles   1995-06-30
# 22                                      Mickey Keating   2016-07-01
# 42                      David Loughery|Doug Richardson   1995-11-22
# 65   Peter Jackson|Philippa Boyens|Guillermo del To...   2012-12-14
# 98                        Ryan Coogler|Aaron Covington   2015-11-25
# 56                                      Eric Heisserer   2011-08-12
# 103                              Zak Penn|Ernest Cline   2018-03-29
# 24                                        Peter Morgan   2010-10-22
# 37                         Mark Neveldine|Brian Taylor   2010-06-18
# 47                                Paul Thomas Anderson   2015-01-09
#
#       dvd_date currency   box_office  ...  \
# 55  2012-07-31        $      5474090  ...
# 73  2012-01-03        $    9,500,000  ...
# 75  2013-04-30        $       63,595  ...
# 6   2013-04-30        $  132,088,910  ...
# 97  2015-03-31        $     10484459  ...
# 20  2016-03-15        $    8,518,148  ...
# 58  2013-11-05        $      1946254  ...
# 61  2014-09-09        $      406,235  ...
# 60  2010-12-01        $     98159963  ...
# 30  2003-01-21        $  121,500,000  ...
# 3   2014-04-01        $   20,518,224  ...
# 96  2004-12-07        $  176,049,130  ...
# 9   2011-11-15        $   35,565,975  ...
# 78  2015-01-06        $   22,838,662  ...
# 63  2017-10-17        $  115,088,305  ...
# 107 2004-09-07        $    355237933  ...
# 22  2016-07-01        $    195243411  ...
# 42  2001-05-22        $    394436586  ...
# 65  2013-03-19        $  303,001,229  ...
# 98  2016-03-01        $   81,157,671  ...
# 56  2011-12-27        $   42,500,000  ...
# 103 2018-07-03        $    607274134  ...
# 24  2011-03-15        $   32,741,596  ...
# 37  2010-10-12        $   10,500,000  ...
# 47  2015-04-28        $    6,100,613  ...
#
#                                            movie popularity  \
# 55                   Once Upon a Time in America     17.717
# 73                                         Drive     15.875
# 75                                Wreck-It Ralph     22.967
# 6                                     Life of Pi     15.000
# 97                                  The Babadook     11.502
# 20                                         Carol     13.096
# 58                                      Deadfall      9.491
# 61                                     Palo Alto      7.262
# 60                                       Killers     10.221
# 30                           The Bourne Identity     17.935
# 3                        The Wolf of Wall Street     29.518
# 96                          The Bourne Supremacy     18.199
# 9                                    Monte Carlo     11.017
# 78                       Guardians of the Galaxy     49.606
# 63   Valerian and the City of a Thousand Planets     24.003
# 107                                    Apollo 13     15.855
# 22                                       The BFG     20.080
# 42                                     Toy Story     28.005
# 65             The Hobbit: An Unexpected Journey     26.939
# 98                             The Good Dinosaur     17.675
# 56                           Final Destination 5     13.392
# 103                             Ready Player One     30.029
# 24                                         Stone      8.401
# 37                                     Jonah Hex     13.467
# 47                                 Inherent Vice     14.244
#
#                                            title vote_average  vote_count  id  \
# 55                   Once Upon a Time in America          8.4        2243  89
# 73                                         Drive          7.5        6737  36
# 75                                Wreck-It Ralph          7.3        7780  31
# 6                                     Life of Pi          7.3        8723  88
# 97                                  The Babadook          6.4        3528  41
# 20                                         Carol          7.4        1949  60
# 58                                      Deadfall          5.9         357  83
# 61                                     Palo Alto          6.4         528  58
# 60                                       Killers          5.8        1314  54
# 30                           The Bourne Identity          7.4        5406  51
# 3                        The Wolf of Wall Street          7.9       12411  76
# 96                          The Bourne Supremacy          7.3        4367  91
# 9                                    Monte Carlo          6.2        1193  84
# 78                       Guardians of the Galaxy          7.9       17958  14
# 63   Valerian and the City of a Thousand Planets          6.6        4149  90
# 107                                    Apollo 13          7.4        2821  75
# 22                                       The BFG          6.2        1916  17
# 42                                     Toy Story          7.9       10174  37
# 65             The Hobbit: An Unexpected Journey          7.2       12076  19
# 98                             The Good Dinosaur          6.7        3135  73
# 56                           Final Destination 5          6.0        1701  49
# 103                             Ready Player One          7.6        7021  78
# 24                                         Stone          5.2         334  50
# 37                                     Jonah Hex          4.6         708  40
# 47                                 Inherent Vice          6.6        1359  56
#
#     release_date  production_budget domestic_gross  worldwide_gross
# 55    1984-06-01         30000000.0      5321508.0     5.575648e+06
# 73    2011-09-16         15000000.0     35060689.0     8.135793e+07
# 75    2012-11-02        165000000.0    189412677.0     4.965115e+08
# 6     2012-11-21        120000000.0    124987022.0     6.209120e+08
# 97    2014-11-28          2000000.0       950792.0     7.482387e+06
# 20    2015-11-20         11800000.0     12711491.0     4.284352e+07
# 58    2012-12-07          6000000.0        66351.0     1.673635e+06
# 61    2014-05-09          1000000.0       767732.0     1.156309e+06
# 60    2010-06-04         75000000.0     47059963.0     9.557275e+07
# 30    2002-06-14         60000000.0    121468960.0     2.143574e+08
# 3     2013-12-25        100000000.0    116900694.0     3.898704e+08
# 96    2004-07-23         85000000.0    176087450.0     3.110011e+08
# 9     2011-07-01         20000000.0     23186769.0     3.968677e+07
# 78    2014-08-01        170000000.0    333172112.0     7.708675e+08
# 63    2017-07-21        180000000.0     40479370.0     2.150984e+08
# 107   1995-06-30         65000000.0    173772767.0     3.358023e+08
# 22    2016-07-01        140000000.0     55483770.0     1.996467e+08
# 42    1995-11-22         30000000.0    191796233.0     3.645455e+08
# 65    2012-12-14        250000000.0    303003568.0     1.017004e+09
# 98    2015-11-25        187500000.0    123087120.0     3.337710e+08
# 56    2011-08-12         40000000.0     42587643.0     1.550112e+08
# 103   2018-03-29        150000000.0    137690172.0     5.792901e+08
# 24    2010-10-08         22000000.0      1810078.0     4.065020e+06
# 37    2010-06-18         47000000.0     10547117.0     1.102270e+07
# 47    2014-12-12         20000000.0      8110975.0     1.477235e+07
#
# [25 rows x 26 columns]

# %%
fufu = zaza_subset.sort_values(by='writer')
fufu.tail(15)
# Out:
#        id_x                                           synopsis rating  \
# 103  1819.0  In the year 2045, people can escape their hars...  PG-13
# 6      57.0  Life doesn't always go according to plan. Pat ...      R
# 8      75.0  Nicolas Cage headlines this high-octane thrill...      R
# 32    469.0  Jacqueline Kennedy Onassis sued him, Marlon Br...  PG-13
# 52    836.0  At the end of the nineteenth century, 16-year-...      R
# 54    964.0  In 1995, during the making of his TV series Tr...     NR
# 59   1046.0  Writer/director Rodrigo Garca (Nine Lives) tea...      R
# 60   1076.0  Bosnia. Rwanda. Kosovo. Sierra Leone. Pakistan...     NR
# 69   1171.0  Academy Award-nominated writer/director J.C. C...  PG-13
# 71   1231.0  THE ROVER, David Michod's highly anticipated f...      R
# 81   1447.0  Ever since his wife was burned in a car crash,...      R
# 82   1487.0  In the highly anticipated sequel, which was in...  PG-13
# 101  1762.0  Adapted from the bestselling novel by author J...  PG-13
# 102  1801.0  Directed by six-time Academy Award (R) nominee...  PG-13
# 104  1822.0  From the team behind Man on Wire comes the sto...  PG-13
#
#                                                  genre  \
# 103   Action and Adventure|Science Fiction and Fantasy
# 6                                               Comedy
# 8            Action and Adventure|Mystery and Suspense
# 32   Documentary|Musical and Performing Arts|Specia...
# 52           Action and Adventure|Mystery and Suspense
# 54                        Documentary|Special Interest
# 59                                               Drama
# 60                        Documentary|Special Interest
# 69           Action and Adventure|Mystery and Suspense
# 71   Mystery and Suspense|Science Fiction and Fanta...
# 81   Art House and International|Drama|Mystery and ...
# 82                                      Comedy|Romance
# 101                                              Drama
# 102                                              Drama
# 104            Art House and International|Documentary
#
#                                               director                 writer  \
# 103                                   Steven Spielberg  Zak Penn|Ernest Cline
# 6                                                  NaN                    NaN
# 8                                      Patrick Lussier                    NaN
# 32                                           Leon Gast                    NaN
# 52                                                 NaN                    NaN
# 54   Jonathan Challis|Susan Crook|John Coffey|Ian L...                    NaN
# 59                                                 NaN                    NaN
# 60                                        Mark Hopkins                    NaN
# 69                                                 NaN                    NaN
# 71                                                 NaN                    NaN
# 81                                                 NaN                    NaN
# 82                                           Tim Story                    NaN
# 101                                      Jake Schreier                    NaN
# 102                                         Peter Weir                    NaN
# 104                                        James Marsh                    NaN
#
#     theater_date   dvd_date currency   box_office  ...  \
# 103   2018-03-29 2018-07-03        $    607274134  ...
# 6     2012-11-21 2013-04-30        $  132,088,910  ...
# 8     2011-02-25 2011-05-31        $   10,706,786  ...
# 32    2010-07-30 2010-10-19        $        2,367  ...
# 52    2015-05-15 2015-07-07        $    380080290  ...
# 54    2012-05-11 2012-10-22        $      104,286  ...
# 59    2010-05-07 2010-12-14        $    1,110,286  ...
# 60    2010-06-04 2010-12-01        $     98159963  ...
# 69    2013-10-18 2014-02-11        $    4,300,353  ...
# 71    2014-06-13 2014-09-23        $      709,133  ...
# 81    2011-10-14 2012-03-06        $    3,185,193  ...
# 82    2014-06-20 2014-09-16        $     70181428  ...
# 101   2015-07-24 2015-10-20        $     91970827  ...
# 102   2011-01-21 2011-04-22        $    2,500,000  ...
# 104   2011-07-08 2012-02-07        $      410,077  ...
#
#                                         movie popularity  \
# 103                          Ready Player One     30.029
# 6                                  Life of Pi     15.000
# 8                                   Hall Pass      9.984
# 32   Cats & Dogs: The Revenge of Kitty Galore     10.544
# 52                         Mad Max: Fury Road     28.099
# 54                               Dark Shadows     15.750
# 59                                 Iron Man 2     28.515
# 60                                    Killers     10.221
# 69                                Escape Plan     17.880
# 71                 How to Train Your Dragon 2     27.106
# 81                                  The Thing     12.349
# 82                       Think Like a Man Too      8.250
# 101                                  Southpaw     25.305
# 102                       No Strings Attached     14.203
# 104                           Horrible Bosses     14.058
#
#                                         title vote_average  vote_count  id  \
# 103                          Ready Player One          7.6        7021  78
# 6                                  Life of Pi          7.3        8723  88
# 8                                   Hall Pass          5.5        1009  57
# 32   Cats & Dogs: The Revenge of Kitty Galore          4.9         273  17
# 52                         Mad Max: Fury Road          7.4       14454  75
# 54                               Dark Shadows          5.9        4197  89
# 59                                 Iron Man 2          6.8       12368  15
# 60                                    Killers          5.8        1314  54
# 69                                Escape Plan          6.7        2799  37
# 71                 How to Train Your Dragon 2          7.7        5589  99
# 81                                  The Thing          6.1        1404  77
# 82                       Think Like a Man Too          6.3         319  36
# 101                                  Southpaw          7.4        3424  92
# 102                       No Strings Attached          6.2        2612  84
# 104                           Horrible Bosses          6.5        3842  34
#
#     release_date  production_budget domestic_gross  worldwide_gross
# 103   2018-03-29        150000000.0    137690172.0      579290136.0
# 6     2012-11-21        120000000.0    124987022.0      620912003.0
# 8     2011-02-25         68000000.0     45060734.0       87173475.0
# 32    2010-07-30         85000000.0     43585753.0      113026383.0
# 52    2015-05-15        150000000.0    153636354.0      370098020.0
# 54    2012-05-11        150000000.0     79727149.0      238202668.0
# 59    2010-05-07        170000000.0    312433331.0      621156389.0
# 60    2010-06-04         75000000.0     47059963.0       95572749.0
# 69    2013-10-18         70000000.0     25135965.0      103735965.0
# 71    2014-06-13        145000000.0    177002924.0      614586270.0
# 81    2011-10-14         38000000.0     16999934.0       27573078.0
# 82    2014-06-20         24000000.0     65028687.0       70027933.0
# 101   2015-07-24         30000000.0     52421953.0       94156456.0
# 102   2011-01-21         25000000.0     70662220.0      149228078.0
# 104   2011-07-08         35000000.0    117538559.0      212417601.0
#
# [15 rows x 26 columns]

# %%
zaza_subset.loc[6, 'writer'] = 'Yann Martel, David Magee'
zaza_subset.loc[52, 'writer'] = 'George Miller, Brendan McCarthy, Nico Lathouris'
zaza_subset.loc[102, 'writer'] = 'Elizabeth Meriwether'
zaza_subset.loc[59, 'writer'] = 'Justin Theroux'
zaza_subset.loc[104, 'writer'] = 'Michael Markowitz, John Francis Daley, Jonathan Goldstein'
zaza_subset.loc[69, 'writer'] = 'Miles Chapman, Arnell Jesko'
zaza_subset.loc[71, 'writer'] = 'Dean DeBlois'
zaza_subset.loc[81, 'writer'] = 'Eric Heisserer'
zaza_subset.loc[82, 'writer'] = 'David A. Newman, Keith Merryman'
zaza_subset.loc[101, 'writer'] = 'Kurt Sutter'
zaza_subset.loc[8, 'writer'] = 'Pete Jones, Peter Farrelly, Kevin Barnett, Bobby Farrelly'
zaza_subset.loc[32, 'writer'] = 'Ron J. Friedman, Steve Bencich'
zaza_subset.loc[54, 'writer'] = 'Seth Grahame-Smith'
zaza_subset.loc[60, 'writer'] = 'Bob DeRosa, Ted Griffin'

# %%
hehe = zaza_subset.sort_values(by='director')
hehe.tail(11)
# Out:
#        id_x                                           synopsis rating  \
# 6      57.0  Life doesn't always go according to plan. Pat ...      R
# 52    836.0  At the end of the nineteenth century, 16-year-...      R
# 57   1013.0  Five-time Academy Award nominee Glenn Close st...      R
# 59   1046.0  Writer/director Rodrigo Garca (Nine Lives) tea...      R
# 63   1114.0  When four lifelong friends-Regina Hall, Queen ...      R
# 69   1171.0  Academy Award-nominated writer/director J.C. C...  PG-13
# 71   1231.0  THE ROVER, David Michod's highly anticipated f...      R
# 77   1318.0  This animated adventure for kids stars Barbie ...     NR
# 81   1447.0  Ever since his wife was burned in a car crash,...      R
# 90   1608.0  A group of air crash survivors are stranded in...  PG-13
# 109  1937.0  Starring Shailene Woodley (Fault in Our Stars,...  PG-13
#
#                                                  genre director  \
# 6                                               Comedy      NaN
# 52           Action and Adventure|Mystery and Suspense      NaN
# 57                                               Drama      NaN
# 59                                               Drama      NaN
# 63                                        Comedy|Drama      NaN
# 69           Action and Adventure|Mystery and Suspense      NaN
# 71   Mystery and Suspense|Science Fiction and Fanta...      NaN
# 77                           Animation|Kids and Family      NaN
# 81   Art House and International|Drama|Mystery and ...      NaN
# 90                          Action and Adventure|Drama      NaN
# 109                                      Drama|Romance      NaN
#
#                                                 writer theater_date  \
# 6                             Yann Martel, David Magee   2012-11-21
# 52     George Miller, Brendan McCarthy, Nico Lathouris   2015-05-15
# 57   Glenn Close|Gabriella Prekop|John Banville|Gab...   2012-01-27
# 59                                      Justin Theroux   2010-05-07
# 63                           Kenya Barris|Tracy Oliver   2017-07-21
# 69                         Miles Chapman, Arnell Jesko   2013-10-18
# 71                                        Dean DeBlois   2014-06-13
# 77                                         Elise Allen   2010-05-01
# 81                                      Eric Heisserer   2011-10-14
# 90                            Edward Burns|Scott Frank   2004-12-17
# 109  Aaron Kandell|Jordan Kandell|David Branson Smi...   2018-06-01
#
#       dvd_date currency   box_office  ...  \
# 6   2013-04-30        $  132,088,910  ...
# 52  2015-07-07        $    380080290  ...
# 57  2012-05-15        $    3,014,541  ...
# 59  2010-12-14        $    1,110,286  ...
# 63  2017-10-17        $  115,088,305  ...
# 69  2014-02-11        $    4,300,353  ...
# 71  2014-09-23        $      709,133  ...
# 77  2010-03-09        $     48190704  ...
# 81  2012-03-06        $    3,185,193  ...
# 90  2005-03-01        $   20,900,803  ...
# 109 2018-08-21        $     16706680  ...
#
#                                                movie popularity  \
# 6                                         Life of Pi     15.000
# 52                                Mad Max: Fury Road     28.099
# 57                                          The Grey     12.942
# 59                                        Iron Man 2     28.515
# 63       Valerian and the City of a Thousand Planets     24.003
# 69                                       Escape Plan     17.880
# 71                        How to Train Your Dragon 2     27.106
# 77                                 Charlie St. Cloud      9.454
# 81                                         The Thing     12.349
# 90   Lemony Snicket's A Series of Unfortunate Events     14.362
# 109                                          Upgrade     21.413
#
#                                                title vote_average  vote_count  \
# 6                                         Life of Pi          7.3        8723
# 52                                Mad Max: Fury Road          7.4       14454
# 57                                          The Grey          6.5        2280
# 59                                        Iron Man 2          6.8       12368
# 63       Valerian and the City of a Thousand Planets          6.6        4149
# 69                                       Escape Plan          6.7        2799
# 71                        How to Train Your Dragon 2          7.7        5589
# 77                                 Charlie St. Cloud          6.9        1398
# 81                                         The Thing          6.1        1404
# 90   Lemony Snicket's A Series of Unfortunate Events          6.8        2975
# 109                                          Upgrade          7.4        1326
#
#      id release_date  production_budget domestic_gross  worldwide_gross
# 6    88   2012-11-21        120000000.0    124987022.0      620912003.0
# 52   75   2015-05-15        150000000.0    153636354.0      370098020.0
# 57   95   2012-01-27         25000000.0     51580136.0       81249176.0
# 59   15   2010-05-07        170000000.0    312433331.0      621156389.0
# 63   90   2017-07-21        180000000.0     40479370.0      215098356.0
# 69   37   2013-10-18         70000000.0     25135965.0      103735965.0
# 71   99   2014-06-13        145000000.0    177002924.0      614586270.0
# 77   31   2010-07-30         44000000.0     31206263.0       48478084.0
# 81   77   2011-10-14         38000000.0     16999934.0       27573078.0
# 90   75   2004-12-17        100000000.0    118627117.0      212956024.0
# 109  89   2018-06-01          3000000.0     11977130.0       16553285.0
#
# [11 rows x 26 columns]

# %%
zaza_subset.loc[6, 'director'] = 'Ang Lee'
zaza_subset.loc[52, 'director'] = 'George Miller'
zaza_subset.loc[57, 'director'] = 'Joe Carnahan'
zaza_subset.loc[59, 'director'] = 'Jon Favreau'
zaza_subset.loc[63, 'director'] = 'Luc Besson'
zaza_subset.loc[69, 'director'] = 'Mikael Håfström'
zaza_subset.loc[71, 'director'] = 'Dean DeBlois'
zaza_subset.loc[77, 'director'] = 'Burr Steers'
zaza_subset.loc[81, 'director'] = 'Matthijs van Heijningen Jr.'
zaza_subset.loc[90, 'director'] = 'Brad Silberling'
zaza_subset.loc[109, 'director'] = 'Leigh Whannell'

# %%
fufu = zaza_subset.sort_values(by='box_office')
fufu.tail(36)
# Out:
#        id_x                                           synopsis rating  \
# 29    419.0  When teens mysteriously develop powerful new a...  PG-13
# 56   1011.0  In Final Destination 5, Death is just as omnip...      R
# 34    486.0  Nanni Moretti joins forces with the great Fren...     NR
# 77   1318.0  This animated adventure for kids stars Barbie ...     NR
# 14    115.0  "Toy Story 2" is the exciting, all-new sequel ...      G
# 11     95.0  BLEED FOR THIS is the incredible true story of...      R
# 50    782.0  THREE BILLBOARDS OUTSIDE EBBING, MISSOURI is a...      R
# 44    643.0  Brigsby Bear Adventures is a children's TV sho...  PG-13
# 72   1236.0  AMERICAN PASTORAL follows Seymour "Swede" Levo...      R
# 55    984.0  A teenager and his kid brother spar with their...  PG-13
# 31    458.0  This is a romantic comedy set in Paris about a...  PG-13
# 43    633.0  One of Filmmaker Magazine's "25 New Faces of I...     NR
# 47    689.0  "Inherent Vice," is the seventh feature from P...      R
# 0       3.0  New York City, not-too-distant-future: Eric Pa...      R
# 103  1819.0  In the year 2045, people can escape their hars...  PG-13
# 75   1268.0  After ten years of marriage, Jeff and Nealy La...      R
# 16    153.0  Meet the kid who made "wimpy" cool in a family...     PG
# 27    387.0  In this western, Will Penny is an aging and im...     NR
# 41    610.0  American tourist Frank (Johnny Depp) meets a m...  PG-13
# 82   1487.0  In the highly anticipated sequel, which was in...  PG-13
# 71   1231.0  THE ROVER, David Michod's highly anticipated f...      R
# 108  1898.0  One of the most expensive films ever produced ...      R
# 113  1968.0  This holiday season, acclaimed filmmaker Camer...     PG
# 62   1113.0  Luke Wilson, Giovanni Ribisi, and Gabriel Mach...      R
# 40    608.0  Some people have bad days. Henry Altmann (Will...      R
# 76   1297.0  Based on true events, WOMAN WALKS AHEAD tells ...      R
# 74   1265.0  Beth (Diane Keaton) saves a bedraggled lost do...  PG-13
# 20    251.0  In this adaptation of the novel "The Price of ...      R
# 91   1639.0  In this darkly erotic drama from cult filmmake...     NR
# 98   1718.0  Adonis Johnson Creed (Michael B. Jordan), the ...  PG-13
# 73   1237.0  Sarah Jessica Parker, Greg Kinnear, Pierce Bro...  PG-13
# 101  1762.0  Adapted from the bestselling novel by author J...  PG-13
# 21    276.0  Carl Reiner directs Steve Martin (who co-wrote...      R
# 110  1944.0  In the 3D action-comedy The Green Hornet, Brit...  PG-13
# 60   1076.0  Bosnia. Rwanda. Kosovo. Sierra Leone. Pakistan...     NR
# 106  1845.0  A group of wealthy boys in Los Angeles during ...      R
#
#                                                  genre  \
# 29    Mystery and Suspense|Science Fiction and Fantasy
# 56                                              Horror
# 34                                        Comedy|Drama
# 77                           Animation|Kids and Family
# 14   Animation|Comedy|Kids and Family|Science Ficti...
# 11                            Drama|Sports and Fitness
# 50                                        Comedy|Drama
# 44                                              Comedy
# 72                                               Drama
# 55                          Drama|Mystery and Suspense
# 31                                      Comedy|Romance
# 43                                               Drama
# 47                          Drama|Mystery and Suspense
# 0                    Drama|Science Fiction and Fantasy
# 103   Action and Adventure|Science Fiction and Fantasy
# 75                                              Comedy
# 16                              Comedy|Kids and Family
# 27       Action and Adventure|Classics|Western|Romance
# 41   Action and Adventure|Mystery and Suspense|Romance
# 82                                      Comedy|Romance
# 71   Mystery and Suspense|Science Fiction and Fanta...
# 108  Action and Adventure|Art House and Internation...
# 113                                       Comedy|Drama
# 62                                        Comedy|Drama
# 40                                        Comedy|Drama
# 76                                               Drama
# 74                                        Comedy|Drama
# 20                                       Drama|Romance
# 91                   Art House and International|Drama
# 98                                               Drama
# 73                                              Comedy
# 101                                              Drama
# 21                                              Comedy
# 110  Action and Adventure|Comedy|Science Fiction an...
# 60                        Documentary|Special Interest
# 106                         Drama|Mystery and Suspense
#
#                              director  \
# 29                Jennifer Yuh Nelson
# 56                       Steven Quale
# 34                      Nanni Moretti
# 77                        Burr Steers
# 14                      John Lasseter
# 11                        Ben Younger
# 50                    Martin McDonagh
# 44                        Dave McCary
# 72                      Ewan McGregor
# 55                      Michael Apted
# 31                        Woody Allen
# 43                           Tze Chun
# 47               Paul Thomas Anderson
# 0                    David Cronenberg
# 103                  Steven Spielberg
# 75                  Jacob Aaron Estes
# 16                   Thor Freudenthal
# 27                          Tom Gries
# 41   Florian Henckel von Donnersmarck
# 82                          Tim Story
# 71                       Dean DeBlois
# 108                        Daniel Lee
# 113                     Cameron Crowe
# 62                       George Gallo
# 40                Phil Alden Robinson
# 76                      Susanna White
# 74                    Lawrence Kasdan
# 20                        Todd Haynes
# 91                     Jeanne Labrune
# 98                       Ryan Coogler
# 73                    Douglas McGrath
# 101                     Jake Schreier
# 21                        Carl Reiner
# 110                     Michel Gondry
# 60                       Mark Hopkins
# 106                         James Cox
#
#                                                 writer theater_date  \
# 29                                          Chad Hodge   2018-08-03
# 56                                      Eric Heisserer   2011-08-12
# 34   Nanni Moretti|Federica Pontremoli|Francesco Pi...   2012-04-06
# 77                                         Elise Allen   2010-05-01
# 14   Doug Chamberlain|Rita Hsiao|Doug Chamberlin|Ch...   1999-11-24
# 11                                         Ben Younger   2016-11-18
# 50                                     Martin McDonagh   2017-12-01
# 44                                      Kevin Costello   2017-07-28
# 72                                         John Romano   2016-10-21
# 55                                          Ron Koslow   1984-06-01
# 31                                         Woody Allen   2011-06-10
# 43                                            Tze Chun   2010-03-12
# 47                                Paul Thomas Anderson   2015-01-09
# 0                         David Cronenberg|Don DeLillo   2012-08-17
# 103                              Zak Penn|Ernest Cline   2018-03-29
# 75                                   Jacob Aaron Estes   2012-11-02
# 16       Jackie Filgo|Jeff Filgo|Gabe Sachs|Jeff Judah   2010-03-19
# 27                                           Tom Gries   1968-04-10
# 41   Florian Henckel von Donnersmarck|Christopher M...   2010-12-10
# 82                     David A. Newman, Keith Merryman   2014-06-20
# 71                                        Dean DeBlois   2014-06-13
# 108                                         Daniel Lee   2015-09-04
# 113                  Aline Brosh McKenna|Cameron Crowe   2011-12-23
# 62                             George Gallo|Andy Weiss   2010-08-06
# 40                                      Daniel Taplitz   2014-05-23
# 76                                       Steven Knight   2018-06-29
# 74                          Lawrence Kasdan|Meg Kasdan   2012-04-20
# 20                                        Phyllis Nagy   2015-11-20
# 91                     Jeanne Labrune|Richard Debuisne   2011-08-26
# 98                        Ryan Coogler|Aaron Covington   2015-11-25
# 73                                 Aline Brosh McKenna   2011-09-16
# 101                                        Kurt Sutter   2015-07-24
# 21            Steve Martin|Carl Gottlieb|Michael Elias   1979-12-14
# 110                           Evan Goldberg|Seth Rogen   2011-01-14
# 60                             Bob DeRosa, Ted Griffin   2010-06-04
# 106                          Captain Mauzner|James Cox   2018-08-17
#
#       dvd_date currency  box_office  ...  \
# 29  2018-10-30        $    41142379  ...
# 56  2011-12-27        $  42,500,000  ...
# 34  2012-09-11        $     480,926  ...
# 77  2010-03-09        $    48190704  ...
# 14  2000-10-17        $   497375381  ...
# 11  2017-02-14        $   5,051,927  ...
# 50  2018-02-27        $  52,000,189  ...
# 44  2017-11-14        $     529,426  ...
# 72  2017-02-07        $     541,457  ...
# 55  2012-07-31        $     5474090  ...
# 31  2011-12-20        $  55,400,000  ...
# 43  2010-08-10        $    56032889  ...
# 47  2015-04-28        $   6,100,613  ...
# 0   2013-01-01        $     600,000  ...
# 103 2018-07-03        $   607274134  ...
# 75  2013-04-30        $      63,595  ...
# 16  2010-08-03        $  64,001,297  ...
# 27  2002-06-04        $    66441232  ...
# 41  2011-03-22        $  67,631,157  ...
# 82  2014-09-16        $    70181428  ...
# 71  2014-09-23        $     709,133  ...
# 108 2015-12-22        $      72,413  ...
# 113 2012-04-03        $  72,700,000  ...
# 62  2011-02-08        $     723,714  ...
# 40  2014-07-22        $   746045700  ...
# 76  2018-08-28        $    75837743  ...
# 74  2012-08-28        $     793,352  ...
# 20  2016-03-15        $   8,518,148  ...
# 91  2012-01-17        $       8,856  ...
# 98  2016-03-01        $  81,157,671  ...
# 73  2012-01-03        $   9,500,000  ...
# 101 2015-10-20        $    91970827  ...
# 21  2005-07-26        $    92455742  ...
# 110 2011-05-03        $  98,000,000  ...
# 60  2010-12-01        $    98159963  ...
# 106 2018-09-18        $    99630675  ...
#
#                                                  movie popularity  \
# 29                                   The Darkest Minds     23.967
# 56                                 Final Destination 5     13.392
# 34                                    American Reunion     17.199
# 77                                   Charlie St. Cloud      9.454
# 14                                         Toy Story 2     22.698
# 11             Fantastic Beasts and Where to Find Them     28.563
# 50                                  The Shape of Water     22.025
# 44                                       Atomic Blonde     21.662
# 72                         Jack Reacher: Never Go Back     17.085
# 55                         Once Upon a Time in America     17.717
# 31                                        Trolljegeren      8.221
# 43                                         Remember Me     11.453
# 47                                       Inherent Vice     14.244
# 0                                    The Expendables 2     17.216
# 103                                   Ready Player One     30.029
# 75                                      Wreck-It Ralph     22.967
# 16                                            Repo Men     12.437
# 27                               2001: A Space Odyssey     23.781
# 41   The Chronicles of Narnia: The Voyage of the Da...     17.382
# 82                                Think Like a Man Too      8.250
# 71                          How to Train Your Dragon 2     27.106
# 108                           The Transporter Refueled     13.428
# 113                                    We Bought a Zoo      9.931
# 62                                          Step Up 3D     17.174
# 40                          X-Men: Days of Future Past     41.867
# 76                         Sicario: Day of the Soldado     29.725
# 74                                       The Lucky One     13.140
# 20                                               Carol     13.096
# 91                                          Colombiana     10.584
# 98                                   The Good Dinosaur     17.675
# 73                                               Drive     15.875
# 101                                           Southpaw     25.305
# 21                                                1941      9.755
# 110                                   Barney's Version      7.357
# 60                                             Killers     10.221
# 106                                              Alpha     24.536
#
#                                                  title vote_average  \
# 29                                   The Darkest Minds          6.8
# 56                                 Final Destination 5          6.0
# 34                                    American Reunion          6.2
# 77                                   Charlie St. Cloud          6.9
# 14                                         Toy Story 2          7.5
# 11             Fantastic Beasts and Where to Find Them          7.4
# 50                                  The Shape of Water          7.2
# 44                                       Atomic Blonde          6.3
# 72                         Jack Reacher: Never Go Back          5.6
# 55                         Once Upon a Time in America          8.4
# 31                                        Troll Hunter          6.7
# 43                                         Remember Me          7.1
# 47                                       Inherent Vice          6.6
# 0                                    The Expendables 2          6.2
# 103                                   Ready Player One          7.6
# 75                                      Wreck-It Ralph          7.3
# 16                                            Repo Men          6.2
# 27                               2001: A Space Odyssey          8.0
# 41   The Chronicles of Narnia: The Voyage of the Da...          6.3
# 82                                Think Like a Man Too          6.3
# 71                          How to Train Your Dragon 2          7.7
# 108                           The Transporter Refueled          5.4
# 113                                    We Bought a Zoo          6.7
# 62                                          Step Up 3D          6.7
# 40                          X-Men: Days of Future Past          7.5
# 76                         Sicario: Day of the Soldado          6.7
# 74                                       The Lucky One          6.9
# 20                                               Carol          7.4
# 91                                          Colombiana          6.5
# 98                                   The Good Dinosaur          6.7
# 73                                               Drive          7.5
# 101                                           Southpaw          7.4
# 21                                                1941          5.7
# 110                                   Barney's Version          7.2
# 60                                             Killers          5.8
# 106                                              Alpha          5.9
#
#      vote_count  id release_date  production_budget domestic_gross  \
# 29         1158  64   2018-08-03         34000000.0     12695691.0
# 56         1701  49   2011-08-12         40000000.0     42587643.0
# 34         2679  26   2012-04-06         50000000.0     56758835.0
# 77         1398  31   2010-07-30         44000000.0     31206263.0
# 14         7553  40   1999-11-19         90000000.0    245852179.0
# 11        12152  85   2016-11-18        180000000.0    234037575.0
# 50         7224  19   2017-12-01         19500000.0     63859435.0
# 44         3645  94   2017-07-28         30000000.0     51573925.0
# 72         2831  85   2016-10-21         60000000.0     58697076.0
# 55         2243  89   1984-06-01         30000000.0      5321508.0
# 31          806  17   2011-06-10          3500000.0       253444.0
# 43         2079  51   2010-03-12         16000000.0     19068240.0
# 47         1359  56   2014-12-12         20000000.0      8110975.0
# 0          4219  81   2012-08-17        100000000.0     85028192.0
# 103        7021  78   2018-03-29        150000000.0    137690172.0
# 75         7780  31   2012-11-02        165000000.0    189412677.0
# 16          976  13   2010-03-19         32000000.0     13942007.0
# 27         5837  27   1968-04-02         10500000.0     59936321.0
# 41         3196  48   2010-12-10        155000000.0    104386950.0
# 82          319  36   2014-06-20         24000000.0     65028687.0
# 71         5589  99   2014-06-13        145000000.0    177002924.0
# 108         836  34   2015-09-04         22000000.0     16029670.0
# 113        1523  14   2011-12-23         50000000.0     75624550.0
# 62         1160   9   2010-08-06         30000000.0     42400223.0
# 40        10062  55   2014-05-23        200000000.0    233921534.0
# 76         1317  59   2018-06-29         35000000.0     50065850.0
# 74         2012  87   2012-04-20         25000000.0     60457138.0
# 20         1949  60   2015-11-20         11800000.0     12711491.0
# 91         1371  60   2011-08-26         40000000.0     36665854.0
# 98         3135  73   2015-11-25        187500000.0    123087120.0
# 73         6737  36   2011-09-16         15000000.0     35060689.0
# 101        3424  92   2015-07-24         30000000.0     52421953.0
# 21          262   4   1979-12-14         32000000.0     34175000.0
# 110         210  86   2011-01-14         30000000.0      7502560.0
# 60         1314  54   2010-06-04         75000000.0     47059963.0
# 106        1167  79   2018-08-17         51000000.0     35851379.0
#
#      worldwide_gross
# 29        38361428.0
# 56       155011165.0
# 34       236799211.0
# 77        48478084.0
# 14       511358276.0
# 11       802402853.0
# 50       195790794.0
# 44        98345423.0
# 72       159946489.0
# 55         5575648.0
# 31         5706638.0
# 43        56506120.0
# 47        14772346.0
# 0        311979256.0
# 103      579290136.0
# 75       496511521.0
# 16        18195238.0
# 27        71928046.0
# 41       418186950.0
# 82        70027933.0
# 71       614586270.0
# 108       69698495.0
# 113      118729073.0
# 62       165889117.0
# 40       747862775.0
# 76        75885196.0
# 74        96633833.0
# 20        42843521.0
# 91        72295262.0
# 98       333771037.0
# 73        81357930.0
# 101       94156456.0
# 21        94875000.0
# 110        8845575.0
# 60        95572749.0
# 106       99624873.0
#
# [36 rows x 26 columns]

# %%
zaza_subset.loc[93, 'title'] = 'Operation Red Sea'
zaza_subset.loc[93, 'movie'] = 'Operation Red Sea'

# %%
zaza_subset['box_office'] = zaza_subset['box_office'].str.replace(',', '')

# %%
zaza_subset['box_office'] = zaza_subset['box_office'].astype(float)

# %%
zaza_subset['total_gross'] = zaza_subset['domestic_gross'] + zaza_subset['worldwide_gross'] + zaza_subset['box_office']
zaza_subset
# Out:
#        id_x                                           synopsis rating  \
# 0       3.0  New York City, not-too-distant-future: Eric Pa...      R
# 1      14.0  "Love Ranch" is a bittersweet love story that ...      R
# 2      22.0  Two-time Academy Award Winner Kevin Spacey giv...      R
# 3      25.0  From ancient Japan's most enduring tale, the e...  PG-13
# 4      54.0  Journalist Jep Gambardella (the dazzling Toni ...     NR
# ..      ...                                                ...    ...
# 110  1944.0  In the 3D action-comedy The Green Hornet, Brit...  PG-13
# 111  1945.0  Left on a nun's doorstep, Larry, Curly and Moe...     PG
# 112  1953.0  A glimpse into the comedic process and private...      R
# 113  1968.0  This holiday season, acclaimed filmmaker Camer...     PG
# 114  1981.0  Money, Fame and the Knowledge of English. In I...     NR
#
#                                                  genre  \
# 0                    Drama|Science Fiction and Fantasy
# 1                                                Drama
# 2                    Comedy|Drama|Mystery and Suspense
# 3    Action and Adventure|Drama|Science Fiction and...
# 4                                         Comedy|Drama
# ..                                                 ...
# 110  Action and Adventure|Comedy|Science Fiction an...
# 111                                             Comedy
# 112                      Comedy|Documentary|Television
# 113                                       Comedy|Drama
# 114                                       Comedy|Drama
#
#                           director  \
# 0                 David Cronenberg
# 1                  Taylor Hackford
# 2              George Hickenlooper
# 3                 Carl Erik Rinsch
# 4                 Paolo Sorrentino
# ..                             ...
# 110                  Michel Gondry
# 111  Bobby Farrelly|Peter Farrelly
# 112      Ricki Stern|Anne Sundberg
# 113                  Cameron Crowe
# 114                   Gauri Shinde
#
#                                          writer theater_date   dvd_date  \
# 0                  David Cronenberg|Don DeLillo   2012-08-17 2013-01-01
# 1                                 Mark Jacobson   2010-06-30 2010-11-09
# 2                                 Norman Snider   2010-12-17 2011-04-05
# 3                    Chris Morgan|Hossein Amini   2013-12-25 2014-04-01
# 4           Paolo Sorrentino|Umberto Contarello   2013-11-15 2014-03-25
# ..                                          ...          ...        ...
# 110                    Evan Goldberg|Seth Rogen   2011-01-14 2011-05-03
# 111  Bobby Farrelly|Peter Farrelly|Mike Cerrone   2012-04-13 2012-07-17
# 112                                 Ricki Stern   2010-06-11 2010-12-14
# 113           Aline Brosh McKenna|Cameron Crowe   2011-12-23 2012-04-03
# 114                                Gauri Shinde   2012-10-05 2012-11-20
#
#     currency  box_office  ... popularity                    title  \
# 0          $    600000.0  ...     17.216        The Expendables 2
# 1          $    134904.0  ...      6.185               Love Ranch
# 2          $   1039869.0  ...     10.395              The Fighter
# 3          $  20518224.0  ...     29.518  The Wolf of Wall Street
# 4          $  24337766.0  ...      9.937         The Great Beauty
# ..       ...         ...  ...        ...                      ...
# 110        $  98000000.0  ...      7.357         Barney's Version
# 111        $  41800000.0  ...     11.273                  Lockout
# 112        $   2927972.0  ...     17.097               The A-Team
# 113        $  72700000.0  ...      9.931          We Bought a Zoo
# 114        $   1416189.0  ...     14.627            Frankenweenie
#
#      vote_average vote_count  id release_date production_budget  \
# 0             6.2       4219  81   2012-08-17       100000000.0
# 1             6.1         28  19   2010-06-30        25000000.0
# 2             7.3       2325  68   2010-12-10        11000000.0
# 3             7.9      12411  76   2013-12-25       100000000.0
# 4             7.4       1518  23   2013-11-15        12000000.0
# ..            ...        ...  ..          ...               ...
# 110           7.2        210  86   2011-01-14        30000000.0
# 111           5.9       1004  22   2012-04-13        20000000.0
# 112           6.3       2703  32   2010-06-11       110000000.0
# 113           6.7       1523  14   2011-12-23        50000000.0
# 114           6.8       1685  48   2012-10-05        39000000.0
#
#      domestic_gross worldwide_gross  total_gross
# 0        85028192.0     311979256.0  397607448.0
# 1          137885.0        146149.0     418938.0
# 2        93617009.0     129262388.0  223919266.0
# 3       116900694.0     389870414.0  527289332.0
# 4         2883879.0      29549145.0   56770790.0
# ..              ...             ...          ...
# 110       7502560.0       8845575.0  114348135.0
# 111      14326865.0      33943049.0   90069914.0
# 112      77222099.0     177241171.0  257391242.0
# 113      75624550.0     118729073.0  267053623.0
# 114      35287788.0      81150788.0  117854765.0
#
# [113 rows x 27 columns]

# %%
zaza_subset.sort_values(by='studio')
# Out:
#        id_x                                           synopsis rating  \
# 29    419.0  When teens mysteriously develop powerful new a...  PG-13
# 40    608.0  Some people have bad days. Henry Altmann (Will...      R
# 111  1945.0  Left on a nun's doorstep, Larry, Curly and Moe...     PG
# 16    153.0  Meet the kid who made "wimpy" cool in a family...     PG
# 113  1968.0  This holiday season, acclaimed filmmaker Camer...     PG
# ..      ...                                                ...    ...
# 56   1011.0  In Final Destination 5, Death is just as omnip...      R
# 103  1819.0  In the year 2045, people can escape their hars...  PG-13
# 24    338.0  "Hereafter" tells the story of three people wh...  PG-13
# 37    554.0  1970s-era DC antihero Jonah Hex makes his way ...  PG-13
# 47    689.0  "Inherent Vice," is the seventh feature from P...      R
#
#                                                 genre  \
# 29   Mystery and Suspense|Science Fiction and Fantasy
# 40                                       Comedy|Drama
# 111                                            Comedy
# 16                             Comedy|Kids and Family
# 113                                      Comedy|Drama
# ..                                                ...
# 56                                             Horror
# 103  Action and Adventure|Science Fiction and Fantasy
# 24                         Drama|Mystery and Suspense
# 37          Action and Adventure|Drama|Horror|Western
# 47                         Drama|Mystery and Suspense
#
#                           director  \
# 29             Jennifer Yuh Nelson
# 40             Phil Alden Robinson
# 111  Bobby Farrelly|Peter Farrelly
# 16                Thor Freudenthal
# 113                  Cameron Crowe
# ..                             ...
# 56                    Steven Quale
# 103               Steven Spielberg
# 24                  Clint Eastwood
# 37                   Jimmy Hayward
# 47            Paul Thomas Anderson
#
#                                             writer theater_date   dvd_date  \
# 29                                      Chad Hodge   2018-08-03 2018-10-30
# 40                                  Daniel Taplitz   2014-05-23 2014-07-22
# 111     Bobby Farrelly|Peter Farrelly|Mike Cerrone   2012-04-13 2012-07-17
# 16   Jackie Filgo|Jeff Filgo|Gabe Sachs|Jeff Judah   2010-03-19 2010-08-03
# 113              Aline Brosh McKenna|Cameron Crowe   2011-12-23 2012-04-03
# ..                                             ...          ...        ...
# 56                                  Eric Heisserer   2011-08-12 2011-12-27
# 103                          Zak Penn|Ernest Cline   2018-03-29 2018-07-03
# 24                                    Peter Morgan   2010-10-22 2011-03-15
# 37                     Mark Neveldine|Brian Taylor   2010-06-18 2010-10-12
# 47                            Paul Thomas Anderson   2015-01-09 2015-04-28
#
#     currency   box_office  ... popularity                       title  \
# 29         $   41142379.0  ...     23.967           The Darkest Minds
# 40         $  746045700.0  ...     41.867  X-Men: Days of Future Past
# 111        $   41800000.0  ...     11.273                     Lockout
# 16         $   64001297.0  ...     12.437                    Repo Men
# 113        $   72700000.0  ...      9.931             We Bought a Zoo
# ..       ...          ...  ...        ...                         ...
# 56         $   42500000.0  ...     13.392         Final Destination 5
# 103        $  607274134.0  ...     30.029            Ready Player One
# 24         $   32741596.0  ...      8.401                       Stone
# 37         $   10500000.0  ...     13.467                   Jonah Hex
# 47         $    6100613.0  ...     14.244               Inherent Vice
#
#      vote_average vote_count  id release_date production_budget  \
# 29            6.8       1158  64   2018-08-03        34000000.0
# 40            7.5      10062  55   2014-05-23       200000000.0
# 111           5.9       1004  22   2012-04-13        20000000.0
# 16            6.2        976  13   2010-03-19        32000000.0
# 113           6.7       1523  14   2011-12-23        50000000.0
# ..            ...        ...  ..          ...               ...
# 56            6.0       1701  49   2011-08-12        40000000.0
# 103           7.6       7021  78   2018-03-29       150000000.0
# 24            5.2        334  50   2010-10-08        22000000.0
# 37            4.6        708  40   2010-06-18        47000000.0
# 47            6.6       1359  56   2014-12-12        20000000.0
#
#      domestic_gross worldwide_gross   total_gross
# 29       12695691.0      38361428.0  9.219950e+07
# 40      233921534.0     747862775.0  1.727830e+09
# 111      14326865.0      33943049.0  9.006991e+07
# 16       13942007.0      18195238.0  9.613854e+07
# 113      75624550.0     118729073.0  2.670536e+08
# ..              ...             ...           ...
# 56       42587643.0     155011165.0  2.400988e+08
# 103     137690172.0     579290136.0  1.324254e+09
# 24        1810078.0       4065020.0  3.861669e+07
# 37       10547117.0      11022696.0  3.206981e+07
# 47        8110975.0      14772346.0  2.898393e+07
#
# [113 rows x 27 columns]

# %%
zaza_subset['profit']= zaza_subset['domestic_gross']- zaza_subset['production_budget'] 
#here we are asuming that everyone is using all of their budget

# %%
zaza_subset['ROI']= zaza_subset['domestic_gross']-zaza_subset['production_budget']

# %%
zaza_subset.sort_values(by='title')
# Out:
#        id_x                                           synopsis rating  \
# 21    276.0  Carl Reiner directs Steve Martin (who co-wrote...      R
# 27    387.0  In this western, Will Penny is an aging and im...     NR
# 106  1845.0  A group of wealthy boys in Los Angeles during ...      R
# 34    486.0  Nanni Moretti joins forces with the great Fren...     NR
# 23    326.0  Unique improvisational techniques are employed...  PG-13
# ..      ...                                                ...    ...
# 63   1114.0  When four lifelong friends-Regina Hall, Queen ...      R
# 53    875.0  Set in the world of electronic music and Holly...      R
# 113  1968.0  This holiday season, acclaimed filmmaker Camer...     PG
# 75   1268.0  After ten years of marriage, Jeff and Nealy La...      R
# 40    608.0  Some people have bad days. Henry Altmann (Will...      R
#
#                                              genre             director  \
# 21                                          Comedy          Carl Reiner
# 27   Action and Adventure|Classics|Western|Romance            Tom Gries
# 106                     Drama|Mystery and Suspense            James Cox
# 34                                    Comedy|Drama        Nanni Moretti
# 23                                    Comedy|Drama           Mike Leigh
# ..                                             ...                  ...
# 63                                    Comedy|Drama           Luc Besson
# 53                                           Drama           Max Joseph
# 113                                   Comedy|Drama        Cameron Crowe
# 75                                          Comedy    Jacob Aaron Estes
# 40                                    Comedy|Drama  Phil Alden Robinson
#
#                                                 writer theater_date  \
# 21            Steve Martin|Carl Gottlieb|Michael Elias   1979-12-14
# 27                                           Tom Gries   1968-04-10
# 106                          Captain Mauzner|James Cox   2018-08-17
# 34   Nanni Moretti|Federica Pontremoli|Francesco Pi...   2012-04-06
# 23                                          Mike Leigh   2010-12-29
# ..                                                 ...          ...
# 63                           Kenya Barris|Tracy Oliver   2017-07-21
# 53                      Max Joseph|Meaghan Oppenheimer   2015-08-28
# 113                  Aline Brosh McKenna|Cameron Crowe   2011-12-23
# 75                                   Jacob Aaron Estes   2012-11-02
# 40                                      Daniel Taplitz   2014-05-23
#
#       dvd_date currency   box_office  ... vote_average vote_count  id  \
# 21  2005-07-26        $   92455742.0  ...          5.7        262   4
# 27  2002-06-04        $   66441232.0  ...          8.0       5837  27
# 106 2018-09-18        $   99630675.0  ...          5.9       1167  79
# 34  2012-09-11        $     480926.0  ...          6.2       2679  26
# 23  2011-06-07        $    3200000.0  ...          7.0        150   8
# ..         ...      ...          ...  ...          ...        ...  ..
# 63  2017-10-17        $  115088305.0  ...          6.6       4149  90
# 53  2015-11-17        $   11122090.0  ...          6.3       1241  20
# 113 2012-04-03        $   72700000.0  ...          6.7       1523  14
# 75  2013-04-30        $      63595.0  ...          7.3       7780  31
# 40  2014-07-22        $  746045700.0  ...          7.5      10062  55
#
#     release_date  production_budget domestic_gross worldwide_gross  \
# 21    1979-12-14         32000000.0     34175000.0      94875000.0
# 27    1968-04-02         10500000.0     59936321.0      71928046.0
# 106   2018-08-17         51000000.0     35851379.0      99624873.0
# 34    2012-04-06         50000000.0     56758835.0     236799211.0
# 23    2010-12-29          8000000.0      3205706.0      20005613.0
# ..           ...                ...            ...             ...
# 63    2017-07-21        180000000.0     40479370.0     215098356.0
# 53    2015-08-28          2000000.0      3591417.0      10153415.0
# 113   2011-12-23         50000000.0     75624550.0     118729073.0
# 75    2012-11-02        165000000.0    189412677.0     496511521.0
# 40    2014-05-23        200000000.0    233921534.0     747862775.0
#
#       total_gross       profit          ROI
# 21   2.215057e+08    2175000.0    2175000.0
# 27   1.983056e+08   49436321.0   49436321.0
# 106  2.351069e+08  -15148621.0  -15148621.0
# 34   2.940390e+08    6758835.0    6758835.0
# 23   2.641132e+07   -4794294.0   -4794294.0
# ..            ...          ...          ...
# 63   3.706660e+08 -139520630.0 -139520630.0
# 53   2.486692e+07    1591417.0    1591417.0
# 113  2.670536e+08   25624550.0   25624550.0
# 75   6.859878e+08   24412677.0   24412677.0
# 40   1.727830e+09   33921534.0   33921534.0
#
# [113 rows x 29 columns]

# %%
zaza_subset['studio'].value_counts()
# Out:
# studio
# Universal Pictures          7
# 20th Century Fox            7
# Sony Pictures Classics      5
# Warner Bros. Pictures       4
# The Weinstein Company       4
#                            ..
# Independent Pictures        1
# Broad Green Pictures        1
# Killer Films                1
# Fox Searchlight Pictures    1
# Eros Entertainment          1
# Name: count, Length: 69, dtype: int64

# %%
zaza_subset['box_office'].max()
# Out:
# 746045700.0

# %% [markdown]
# # Combos are done!
# now that we've combined our data and filterd out rows we can look at the visualisations that are relevant.

# %%
studio_box_office = zaza_subset.groupby('title')['box_office'].sum()

top_15_studios = studio_box_office.sort_values(ascending=False).head(15)

plt.figure(figsize=(10, 6))
top_15_studios.plot(kind='bar')
plt.title('Top 15 movies')
plt.xlabel('title')
plt.ylabel('Total Box Office In Millions')
plt.xticks(rotation=90)
plt.show()

# %%
grossing = zaza_subset.groupby('title')['total_gross'].sum()

top_15_gross = studio_box_office.sort_values(ascending=False).head(15)

plt.figure(figsize=(10, 6))
top_15_studios.plot(kind='bar')
plt.title('Top 15 movies')
plt.xlabel('title')
plt.ylabel('Gross In Millions')
plt.xticks(rotation=90)
plt.show()

# %%
print(zaza_subset.columns)
# Out:
# Index(['id_x', 'synopsis', 'rating', 'genre', 'director', 'writer',
#        'theater_date', 'dvd_date', 'currency', 'box_office', 'runtime',
#        'studio', 'Unnamed: 0', 'genre_ids', 'id_y', 'original_language',
#        'movie', 'popularity', 'title', 'vote_average', 'vote_count', 'id',
#        'release_date', 'production_budget', 'domestic_gross',
#        'worldwide_gross', 'total_gross', 'profit', 'ROI'],
#       dtype='object')

# %%
zaza_subset['release_date'] = pd.to_datetime(zaza_subset['release_date'])

# Extract month from release_date
zaza_subset['month'] = zaza_subset['release_date'].dt.month

# Calculate the average total_gross for each month
avg_gross_per_month = zaza_subset.groupby('month')['total_gross'].mean()

# Plotting
plt.figure(figsize=(12, 6))
avg_gross_per_month.plot(kind='bar', color='skyblue')
plt.title('Average Total Gross per Month')
plt.xlabel('Month')
plt.ylabel('Average Total Gross')
plt.xticks(ticks=range(12), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.tight_layout()
plt.show()

# %%
# Calculate the average popularity for each director
avg_popularity_per_director = zaza_subset.groupby('director')['popularity'].mean().sort_values(ascending=False)

# Plotting
plt.figure(figsize=(12, 6))
avg_popularity_per_director.plot(kind='bar', color='lightgreen')
plt.title('Average Movie Popularity by Director')
plt.xlabel('Director')
plt.ylabel('Average Popularity')
plt.tight_layout()
plt.show()

# %%
# Calculate the average rating for each director and pick top N (e.g., 5)
N = 5
top_directors = zaza_subset.groupby('director')['vote_average'].mean().nlargest(N)

# Plotting
plt.figure(figsize=(12, 6))
top_directors.plot(kind='bar', color='lightcoral')
plt.title('Top Directors by Average Rating')
plt.xlabel('Director')
plt.ylabel('Average Rating')
plt.ylim(0, 10)  # Assuming ratings are out of 10
plt.tight_layout()
plt.show()

# %%
quantile_90 = zaza_subset['vote_average'].quantile(0.90)
highest_ratings = zaza_subset[zaza_subset['vote_average'] > quantile_90]['vote_average']

plt.figure(figsize=(12, 6))
plt.hist(highest_ratings, bins=20, color='lightcoral', edgecolor='black')
plt.title('Distribution of Top 10% Highest Ratings')
plt.xlabel('Rating')
plt.ylabel('Number of Movies')
plt.xlim(0, 10)  # Assuming ratings are out of 10
plt.tight_layout()
plt.show()

# %%
studio_counts = zaza_subset['studio'].value_counts()

# Plotting
plt.figure(figsize=(12, 6))
studio_counts.plot(kind='bar', color='lightblue')
plt.title('Number of Movies Produced by Each Studio')
plt.xlabel('Studio')
plt.ylabel('Number of Movies')
plt.tight_layout()
plt.show()

# %%
studio_counts = zaza_subset['studio'].value_counts().head(10)
# Plotting
plt.figure(figsize=(12, 6)) 
studio_counts.plot(kind='bar', color='lightblue') 
plt.title('Number of Movies Produced by Each Studio') 
plt.xlabel('Studio')
plt.ylabel('Number of Movies')
plt.tight_layout()
plt.show()

# %%
# Calculate the average total_gross for each genre
# If you want total instead of average, replace 'mean' with 'sum' 
average_gross_per_genre = zaza_subset.groupby('genre')['total_gross'].mean()
# Plotting
plt.figure(figsize=(12, 6)) 
average_gross_per_genre.sort_values(ascending=True).plot(kind='barh', color='lightseagreen') 
plt.title('Average Gross Earnings by Genre')
plt.xlabel('Average Gross Earnings')
plt.ylabel('Genre')
plt.tight_layout()
plt.show()

# %%
#zaza_subset['profit'].min()

# %%
average_gross_per_genre = zaza_subset.groupby('genre')['profit'].mean().head(10)
# Plotting
plt.figure(figsize=(12, 6)) 
average_gross_per_genre.sort_values(ascending=True).plot(kind='barh', color='lightseagreen') 
plt.title('Average Profit by Genre')
plt.xlabel('Average Profit (100s of millions)')
plt.ylabel('Genre Count')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt 
import pandas as pd
#Assuming the 'release_date' column is in date format, if not, convert it to date format
zaza_subset['release_date'] = pd.to_datetime(zaza_subset['release_date']) 
#Extract month from release_date
zaza_subset['month'] = zaza_subset['release_date'].dt.month 
#Calculate the average vote_average for each month
avg_vote_average_per_month = zaza_subset.groupby('month')['vote_average'].mean()
#Plotting
plt.figure(figsize=(12, 6))
avg_vote_average_per_month.plot(kind='bar', color='green')
plt.title('Average Vote Average per Month')
plt.xlabel('Month')
plt.ylabel('Average Vote Average')
plt.xticks(ticks=range(0, 12), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt 
import pandas as pd
# Assuming you have a 'studio' column and a 'profit' column in your DataFrame # Group the data by 'studio' and calculate the total profit for each studio 
studio_profit = zaza_subset.groupby('studio')['profit'].sum().reset_index()
# Sort the data by total profit in descending order to find the studio with the most profit
studio_profit = studio_profit.sort_values(by='profit', ascending=False)
# Create a bar plot
plt.figure(figsize=(12, 6))
plt.bar(studio_profit['studio'], studio_profit['profit'], color='skyblue') 
plt.title('Total Profit by Studio')
plt.xlabel('Studio')
plt.ylabel('Total Profit')
plt.xticks(rotation=90) # Rotate x-axis labels for better readability (optional) plt.tight_layout()
plt.show()

# %%
studio_profit = zaza_subset.groupby('studio')['profit'].sum().reset_index()
# Sort the data by total profit in descending order to find the studio with the most profit
studio_profit = studio_profit.sort_values(by='profit', ascending=False) 
studio_profit= studio_profit.head(10)
# Create a bar plot
plt.figure(figsize=(12, 6))
plt.bar(studio_profit['studio'], studio_profit['profit'], color='skyblue') 
plt.title('Total Profit by Studio')
plt.xlabel('Studio')
plt.ylabel('Total Profit in Millions')
plt.xticks(rotation=90) # Rotate x-axis labels for better readability (optional) plt.tight_layout()
plt.show()

# %%
studio_profit = zaza_subset.groupby('title')['profit'].sum().reset_index()
# Sort the data by total profit in descending order to find the studio with the most profit
studio_profit = studio_profit.sort_values(by='profit', ascending=False) 
studio_profit= studio_profit.head(10)
# Create a bar plot
plt.figure(figsize=(12, 6))
plt.bar(studio_profit['title'], studio_profit['profit'], color='skyblue') 
plt.title('Total Profit by title')
plt.xlabel('title')
plt.ylabel('Total Profit in Millions')
plt.xticks(rotation=90) # Rotate x-axis labels for better readability (optional) plt.tight_layout()
plt.show()

# %% [markdown]
# # Director

# %%
studio_profit = zaza_subset.groupby('director')['profit'].sum().reset_index()
# Sort the data by total profit in descending order to find the studio with the most profit
studio_profit = studio_profit.sort_values(by='profit', ascending=False) 
studio_profit= studio_profit.head(10)
# Create a bar plot
plt.figure(figsize=(12, 6))
plt.bar(studio_profit['director'], studio_profit['profit'], color='skyblue') 
plt.title('Total Profit by director')
plt.xlabel('director')
plt.ylabel('Total Profit in Millions')
plt.xticks(rotation=90) # Rotate x-axis labels for better readability (optional) plt.tight_layout()
plt.show()

# %%
N = 10
top_directors = zaza_subset.groupby('director')['vote_average'].mean().nlargest(N)
# Plotting
plt.figure(figsize=(12, 6)) 
top_directors.plot(kind='bar', color='lightcoral') 
plt.title('Top Directors by Average Rating') 
plt.xlabel('Director')
plt.ylabel('Average Rating')
plt.ylim(0, 10) # Assuming ratings are out of 10 plt.tight_layout()
plt.show()

# %%
avg_popularity_per_director = zaza_subset.groupby('director')['popularity'].mean().sort_values()
avg_popularity_per_director= avg_popularity_per_director.head(10)
# Plotting
plt.figure(figsize=(12, 6))
avg_popularity_per_director.plot(kind='bar', color='pink') 
plt.title('Average Movie Popularity by Director') 
plt.xlabel('Director')
plt.ylabel('Average Popularity')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Months

# %%
zaza_subset['release_date'] = pd.to_datetime(zaza_subset['release_date']) 
#Extract month from release_date
zaza_subset['month'] = zaza_subset['release_date'].dt.month 
#Calculate the average total_gross for each month
avg_gross_per_month = zaza_subset.groupby('month')['profit'].mean()
# Plotting
plt.figure(figsize=(12, 6))
avg_gross_per_month.plot(kind='bar', color='skyblue')
plt.title('Average Total Profit per Month')
plt.xlabel('Month')
plt.ylabel('Average Total Profit')
plt.xticks(ticks=range(12), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.tight_layout()
plt.show()

# %%
zaza_subset['release_date'] = pd.to_datetime(zaza_subset['release_date']) 
#Extract month from release_date
zaza_subset['month'] = zaza_subset['release_date'].dt.month 
#Calculate the average total_gross for each month
avg_gross_per_month = zaza_subset.groupby('month')['popularity'].mean()
# Plotting
plt.figure(figsize=(12, 6))
avg_gross_per_month.plot(kind='bar', color='skyblue')
plt.title('Average Pop Months')
plt.xlabel('Month')
plt.ylabel('Average Pop')
plt.xticks(ticks=range(12), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']) 
plt.tight_layout()
plt.show()

# %%
zaza_subset['release_date'] = pd.to_datetime(zaza_subset['release_date']) # Extract month from release_date
zaza_subset['month'] = zaza_subset['release_date'].dt.month # Calculate the average total_gross for each month
avg_gross_per_month = zaza_subset.groupby('month')['vote_average'].mean()
# Plotting
plt.figure(figsize=(12, 6))
avg_gross_per_month.plot(kind='bar', color='skyblue')
plt.title('Average Pop Months')
plt.xlabel('Month')
plt.ylabel('Average Pop')
plt.xticks(ticks=range(12), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']) 
plt.tight_layout()
plt.show()

# %% [markdown]
# # Genre

# %%
zaza_subset['popularity'].max()
# Out:
# 49.606

# %%
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np
# Assuming you have a DataFrame named 'zaza_subset' with a 'director' column and a 'genre' col 
# Calculate the popularity of each director (sum of popularity of their movies) 
director_popularity = zaza_subset.groupby('director')['popularity'].sum().reset_index()
# Select the top 20 most popular directors
top_20_directors = director_popularity.nlargest(20, 'popularity')
# Create a scatter plot with switched x and y axes for the top 20 directors and their genres
plt.figure(figsize=(12, 6))
# Generate unique colors for each director
unique_directors = top_20_directors['director'].unique()
colors = plt.cm.tab20(np.linspace(0, 1, len(unique_directors)))
# Dictionary to store data points by genre
genre_data_dict = {}
for i, director in enumerate(unique_directors):
    director_data = zaza_subset[zaza_subset['director'] == director] 
    # Get the unique genres for the director's movies
    genres = director_data['genre'].unique()
    # Create a scatter plot for each genre
    for genre in genres:
        genre_data = director_data[director_data['genre'] == genre]
        # Store data points by genre in the dictionary
    if genre not in genre_data_dict: 
        genre_data_dict[genre] = {'x': [], 'y': []}
       
        genre_data_dict[genre]['x'].extend([i] * len(genre_data)) 
        genre_data_dict[genre]['y'].extend(genre_data['genre'])
        plt.scatter([i] * len(genre_data), genre_data['genre'], c=colors[i], label=genre, alpha=0.5)
# Plot lines connecting data points with the same genre
for genre, data in genre_data_dict.items():
    plt.plot(data['x'], data['y'], linestyle='-', linewidth=0.8, color='gray', alpha=0.5)
plt.title('Scatter Plot of Movie Ratings by Director (Top 20 Most Popular Directors)') 
plt.xlabel('Director')
plt.ylabel('Genre')
plt.xticks(range(len(unique_directors)), unique_directors, rotation=90) 
plt.tight_layout()
plt.show()
# Out:
# /var/folders/1f/98thg_p17ml4vwvv3m9xpp380000gn/T/ipykernel_23312/10996036.py:29: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter([i] * len(genre_data), genre_data['genre'], c=colors[i], label=genre, alpha=0.5)

# %%
import matplotlib.pyplot as plt 
import pandas as pd
# Assuming you have a DataFrame named 'zaza_subset' with a 'genre' column and a 'director' col # Filter the DataFrame to select only rows with 'Drama' genre
drama_movies = zaza_subset[zaza_subset['genre'] == 'Drama']
# Count the number of drama movies made by each director
director_drama_counts = drama_movies['director'].value_counts().reset_index() 
director_drama_counts.columns = ['Director', 'Drama Movie Count']
# Sort the data by the count of drama movies in descending order
director_drama_counts = director_drama_counts.sort_values(by='Drama Movie Count', ascending=False)
# Create a bar chart
plt.figure(figsize=(12, 6))
plt.bar(director_drama_counts['Director'], director_drama_counts['Drama Movie Count']) 
plt.title('Number of Drama Movies by Director')
plt.xlabel('Director')
plt.ylabel('Number of Drama Movies')
plt.xticks(rotation=90) # Rotate x-axis labels for better readability (optional) plt.tight_layout()
plt.show()

# %%
genre_max_popularity = zaza_subset.groupby('genre')['popularity'].max().reset_index()
# Sort the data by maximum popularity in descending order
genre_max_popularity = genre_max_popularity.sort_values(by='popularity', ascending=False) 
genre_max_popularity= genre_max_popularity.head(10)
# Create a bar plot
plt.figure(figsize=(12, 8))
plt.bar(genre_max_popularity['genre'], genre_max_popularity['popularity'], color='skyblue') 
plt.title('Highest Popularity in Each Genre')
plt.xlabel('Genre')
plt.ylabel('Maximum Popularity')
plt.xticks(rotation=90) # Rotate x-axis labels for better readability (optional) plt.tight_layout()
plt.show()

# %%
genre_max_vote_average = zaza_subset.groupby('genre')['vote_average'].max().reset_index()
# Sort the data by maximum vote_average in descending order
genre_max_vote_average = genre_max_vote_average.sort_values(by='vote_average', ascending=False) 
genre_max_vote_average= genre_max_vote_average.head(10)
# Create a bar chart
plt.figure(figsize=(12, 8))
plt.bar(genre_max_vote_average['genre'], genre_max_vote_average['vote_average'], color='skyblue') 
plt.title('Highest Vote Average in Each Genre (Bar Chart)')
plt.xlabel('Genre')
plt.ylabel('Maximum Vote Average')
plt.xticks(rotation=90) # Rotate x-axis labels for better readability (optional) plt.tight_layout()
plt.show()

# %%
genre_max_popularity = zaza_subset.groupby('genre')['profit'].max().reset_index()
# Sort the data by maximum popularity in descending order
genre_max_popularity = genre_max_popularity.sort_values(by='profit', ascending=False) 
genre_max_popularity= genre_max_popularity.head(10)
# Create a bar plot
plt.figure(figsize=(12, 8))
plt.bar(genre_max_popularity['genre'], genre_max_popularity['profit'], color='skyblue') 
plt.title('Highest Profit in Each Genre')
plt.xlabel('Genre')
plt.ylabel('Maximum Profit')
plt.xticks(rotation=90) # Rotate x-axis labels for better readability (optional) plt.tight_layout()
plt.show()

# %% [markdown]
# # Studio

# %%
genre_max_popularity = zaza_subset.groupby('studio')['popularity'].max().reset_index()
# Sort the data by maximum popularity in descending order
genre_max_popularity = genre_max_popularity.sort_values(by='popularity', ascending=False) 
genre_max_popularity= genre_max_popularity.head(10)
# Create a bar plot
plt.figure(figsize=(12, 6))
plt.bar(genre_max_popularity['studio'], genre_max_popularity['popularity'], color='skyblue') 
plt.title('Highest Popularity in Each studio')
plt.xlabel('studio')
plt.ylabel('Maximum Popularity')
plt.xticks(rotation=90) # Rotate x-axis labels for better readability (optional) plt.tight_layout()
plt.show()

# %%
genre_max_vote_average = zaza_subset.groupby('studio')['vote_average'].max().reset_index()
# Sort the data by maximum vote_average in descending order
genre_max_vote_average = genre_max_vote_average.sort_values(by='vote_average', ascending=False) 
genre_max_vote_average= genre_max_vote_average.head(10)
# Create a bar chart
plt.figure(figsize=(12, 6))
plt.bar(genre_max_vote_average['studio'], genre_max_vote_average['vote_average'], color='skyblue') 
plt.title('Highest Vote Average in Each studio (Bar Chart)')
plt.xlabel('Genre')
plt.ylabel('Maximum Vote Average')
plt.xticks(rotation=90) # Rotate x-axis labels for better readability (optional) plt.tight_layout()
plt.show()

# %%
genre_max_popularity = zaza_subset.groupby('studio')['profit'].max().reset_index()
# Sort the data by maximum popularity in descending order
genre_max_popularity = genre_max_popularity.sort_values(by='profit', ascending=False) 
genre_max_popularity= genre_max_popularity.head(10)
# Create a bar plot
plt.figure(figsize=(12, 8))
plt.bar(genre_max_popularity['studio'], genre_max_popularity['profit'], color='green') 
plt.title('Highest Profit in Each studio')
plt.xlabel('studio')
plt.ylabel('Maximum Profit')
plt.xticks(rotation=90) # Rotate x-axis labels for better readability (optional) plt.tight_layout()
plt.show()

# %% [markdown]
# # Rating

# %%
genre_max_popularity = zaza_subset.groupby('rating')['profit'].max().reset_index()
# Sort the data by maximum popularity in descending order
genre_max_popularity = genre_max_popularity.sort_values(by='profit', ascending=False) 
genre_max_popularity= genre_max_popularity.head(10)
# Create a bar plot
plt.figure(figsize=(12, 8))
plt.bar(genre_max_popularity['rating'], genre_max_popularity['profit'], color='green') 
plt.title('Highest Profit in Each rating')
plt.xlabel('rating')
plt.ylabel('Maximum Profit')
plt.xticks(rotation=90) # Rotate x-axis labels for better readability (optional) plt.tight_layout()
plt.show()

# %%
genre_max_vote_average = zaza_subset.groupby('rating')['vote_average'].max().reset_index()
# Sort the data by maximum vote_average in descending order
genre_max_vote_average = genre_max_vote_average.sort_values(by='vote_average', ascending=False) 
genre_max_vote_average= genre_max_vote_average.head(10)
# Create a bar chart
plt.figure(figsize=(12, 6))
plt.bar(genre_max_vote_average['rating'], genre_max_vote_average['vote_average'], color='skyblue') 
plt.title('Highest Vote Average in Each rating (Bar Chart)')
plt.xlabel('rating')
plt.ylabel('Maximum Vote Average')
plt.xticks(rotation=90) # Rotate x-axis labels for better readability (optional) plt.tight_layout()
plt.show()

# %%
genre_max_vote_average = zaza_subset.groupby('rating')['popularity'].max().reset_index()
# Sort the data by maximum vote_average in descending order
genre_max_vote_average = genre_max_vote_average.sort_values(by='popularity', ascending=False) 
genre_max_vote_average= genre_max_vote_average.head(10)
# Create a bar chart
plt.figure(figsize=(12, 6))
plt.bar(genre_max_vote_average['rating'], genre_max_vote_average['popularity'], color='red') 
plt.title('Highest Vote Average in Each rating (Bar Chart)')
plt.xlabel('rating')
plt.ylabel('Maximum Vote Average')
plt.xticks(rotation=90) # Rotate x-axis labels for better readability (optional) plt.tight_layout()
plt.show()

# %%
drama_movies = zaza_subset[zaza_subset['rating'] == 'PG-13'] 
# Get the unique directors of drama movies
unique_drama_directors = drama_movies['director'].unique()
# Print or display the list of directors who have made drama movies
print("Directors who have made Drama movies:") 
for director in unique_drama_directors:
    print(director)
# Out:
# Directors who have made Drama movies:
# Carl Erik Rinsch
# Pat Proft
# Tom Hanks
# Derek Cianfrance
# Mike Leigh
# Clint Eastwood
# Roger Donaldson
# Jennifer Yuh Nelson
# Doug Liman
# Woody Allen
# Leon Gast
# Jimmy Hayward
# Florian Henckel von Donnersmarck
# Dave McCary
# Michael Apted
# Edward Burns
# Peter Jackson
# Michael Urie
# David Gelb
# Mikael Håfström
# Douglas McGrath
# Lawrence Kasdan
# Tate Taylor
# Youssef Delara
# Mike Binder
# Tim Story
# Shana Feste
# Sam Mendes
# Brad Silberling
# Paul Greengrass
# Morten Tyldum
# Ryan Coogler
# Trish Sie
# Jake Schreier
# Peter Weir
# Steven Spielberg
# James Marsh
# Leigh Whannell
# Michel Gondry
